# %% [markdown]
# ####  Test hyperopt

# %% [markdown]
# ### Case.1 : 　Classification Case: Quote from "Data Analysis Technic to win at  Kaggle"

# %%
#!pip install hyperopt

# %%
# ---------------------------------
# データ等の準備
# ----------------------------------
import numpy as np
import pandas as pd

# train_xは学習データ、train_yは目的変数、test_xはテストデータ
# pandasのDataFrame, Seriesで保持します。（numpyのarrayで保持することもあります）

train = pd.read_csv('./sample-data/train_preprocessed.csv')
train_x = train.drop(['target'], axis=1)
train_y = train['target']
#test_x = pd.read_csv('./input/sample-data/test_preprocessed.csv')

# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# xgboostによる学習・予測を行うクラス
import xgboost as xgb


class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {'objective': 'binary:logistic', 'silent': 1, 'random_state': 71}
        params.update(self.params)
        num_round = 50
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.quniform('min_child_weight', 1, 5, 1),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'gamma': hp.quniform('gamma', 0, 0.4, 0.1),
}

# hyperoptによるパラメータ探索の実行
max_evals = 10
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.154	eval-error:0.1624
#
# [1]	train-error:0.1476	eval-error:0.1604
#
# [2]	train-error:0.138533	eval-error:0.1512
#
# [3]	train-error:0.1416	eval-error:0.1516
#
# [4]	train-error:0.1348	eval-error:0.1456
#
# [5]	train-error:0.129867	eval-error:0.1428
#
# [6]	train-error:0.1272	eval-error:0.1404
#
# [7]	train-error:0.122267	eval-error:0.1424
#
# [8]	train-error:0.118933	eval-error:0.136
#
# [9]	train-error:0.115867	eval-error:0.1324
#
# [10]	train-error:0.110667	eval-error:0.1348
#
# [11]	train-error:0.106933	eval-error:0.1284
#
# [12]	train-error:0.106933	eval-error:0.1276
#
# [13]	train-error:0.103733	eval-error:0.1244
#
# [14]	train-error:0.098533	eval-error:0.12
#
# [15]	train-error:0.096667	eval-error:0.12
#
#   0%|                                                                           | 0/10 [00:00<?, ?trial/s, best loss=?]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [16]	train-error:0.094133	eval-error:0.1196
#
# [17]	train-error:0.093467	eval-error:0.1192
#
# [18]	train-error:0.0908	eval-error:0.1208
#
# [19]	train-error:0.088533	eval-error:0.1188
#
# [20]	train-error:0.084533	eval-error:0.12
#
# [21]	train-error:0.082667	eval-error:0.1196
#
# [22]	train-error:0.078667	eval-error:0.1164
#
# [23]	train-error:0.077867	eval-error:0.114
#
# [24]	train-error:0.0752	eval-error:0.1144
#
# [25]	train-error:0.0752	eval-error:0.1148
#
# [26]	train-error:0.072933	eval-error:0.1124
#
# [27]	train-error:0.072	eval-error:0.112
#
# [28]	train-error:0.070533	eval-error:0.1084
#
# [29]	train-error:0.068133	eval-error:0.1064
#
# [30]	train-error:0.068133	eval-error:0.1076
#
# [31]	train-error:0.064667	eval-error:0.106
#
# [32]	train-error:0.0636	eval-error:0.1068
#
# [33]	train-error:0.062667	eval-error:0.1048
#
# [34]	train-error:0.062	eval-error:0.1024
#
# [35]	train-error:0.06	eval-error:0.1044
#
# [36]	train-error:0.0596	eval-error:0.1036
#
# [37]	train-error:0.058667	eval-error:0.1008
#
# [38]	train-error:0.057867	eval-error:0.1004
#
# [39]	train-error:0.0576	eval-error:0.1004
#
# [40]	train-error:0.0564	eval-error:0.1012
#
# [41]	train-error:0.055333	eval-error:0.1
#
# [42]	train-error:0.054267	eval-error:0.1004
#
# [43]	train-error:0.0544	eval-error:0.1008
#
# [44]	train-error:0.052133	eval-error:0.1004
#
# [45]	train-error:0.051067	eval-error:0.098
#
# [46]	train-error:0.050267	eval-error:0.098
#
# [47]	train-error:0.05	eval-error:0.0992
#
# [48]	train-error:0.048267	eval-error:0.0992
#
# [49]	train-error:0.048133	eval-error:0.0976
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 4, 'min_child_weight': 3.0}, logloss: 0.2283
# [0]	train-error:0.154	eval-error:0.1624
#
# [1]	train-error:0.1476	eval-error:0.1604
#
# [2]	train-error:0.138533	eval-error:0.1524
#
# [3]	train-error:0.1428	eval-error:0.1508
#
# [4]	train-error:0.131333	eval-error:0.1452
#
# [5]	train-error:0.1288	eval-error:0.146
#
# [6]	train-error:0.128267	eval-error:0.1448
#
# [7]	train-error:0.122933	eval-error:0.1428
#
# [8]	train-error:0.1184	eval-error:0.136
#
# [9]	train-error:0.1128	eval-error:0.1304
#
# [10]	train-error:0.111467	eval-error:0.132
#
# [11]	train-error:0.105067	eval-error:0.1276
#
# [12]	train-error:0.103067	eval-error:0.1248
#
# [13]	train-error:0.101467	eval-error:0.1212
#
# [14]	train-error:0.094133	eval-error:0.1208
#
# [15]	train-error:0.0916	eval-error:0.1184
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [16]	train-error:0.089467	eval-error:0.116
#
# [17]	train-error:0.088533	eval-error:0.112
#
# [18]	train-error:0.083733	eval-error:0.112
#
# [19]	train-error:0.082933	eval-error:0.1096
#
# [20]	train-error:0.0812	eval-error:0.108
#
# [21]	train-error:0.081467	eval-error:0.1092
#
# [22]	train-error:0.079867	eval-error:0.1108
#
# [23]	train-error:0.0764	eval-error:0.1072
#
# [24]	train-error:0.074267	eval-error:0.11
#
# [25]	train-error:0.074267	eval-error:0.1104
#
# [26]	train-error:0.072933	eval-error:0.1068
#
# [27]	train-error:0.072133	eval-error:0.1076
#
# [28]	train-error:0.068933	eval-error:0.108
#
# [29]	train-error:0.065733	eval-error:0.1028
#
# [30]	train-error:0.0648	eval-error:0.1032
#
# [31]	train-error:0.064133	eval-error:0.1032
#
# [32]	train-error:0.063867	eval-error:0.102
#
# [33]	train-error:0.060533	eval-error:0.1
#
# [34]	train-error:0.059733	eval-error:0.1016
#
# [35]	train-error:0.059733	eval-error:0.0984
#
# [36]	train-error:0.058533	eval-error:0.0984
#
# [37]	train-error:0.056533	eval-error:0.0976
#
# [38]	train-error:0.055333	eval-error:0.0988
#
# [39]	train-error:0.055067	eval-error:0.096
#
# [40]	train-error:0.054	eval-error:0.0956
#
# [41]	train-error:0.052267	eval-error:0.0932
#
# [42]	train-error:0.052267	eval-error:0.0932
#
# [43]	train-error:0.050133	eval-error:0.0944
#
# [44]	train-error:0.049733	eval-error:0.0932
#
# [45]	train-error:0.048667	eval-error:0.0928
#
# [46]	train-error:0.047867	eval-error:0.0952
#
# [47]	train-error:0.0472	eval-error:0.0964
#
# [48]	train-error:0.047467	eval-error:0.0948
#
# [49]	train-error:0.045867	eval-error:0.0932
#
# params: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 4.0}, logloss: 0.2201
# [0]	train-error:0.142133	eval-error:0.1564
#
# [1]	train-error:0.134533	eval-error:0.1516
#
# [2]	train-error:0.1268	eval-error:0.1452
#
# [3]	train-error:0.123467	eval-error:0.1424
#
# [4]	train-error:0.115867	eval-error:0.138
#
# [5]	train-error:0.1132	eval-error:0.1372
#
# [6]	train-error:0.1096	eval-error:0.1396
#
# [7]	train-error:0.104533	eval-error:0.1352
#
# [8]	train-error:0.100667	eval-error:0.134
#
# [9]	train-error:0.098267	eval-error:0.1272
#
# [10]	train-error:0.091467	eval-error:0.1264
#
# [11]	train-error:0.088133	eval-error:0.1212
#
# [12]	train-error:0.084667	eval-error:0.1232
#
# [13]	train-error:0.081067	eval-error:0.1212
#
# [14]	train-error:0.0792	eval-error:0.1176
#
# [15]	train-error:0.0772	eval-error:0.116
#
#  20%|█████████▌                                      | 2/10 [00:01<00:04,  1.87trial/s, best loss: 0.22007550967978315]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [16]	train-error:0.074933	eval-error:0.1136
#
# [17]	train-error:0.073067	eval-error:0.1108
#
# [18]	train-error:0.0696	eval-error:0.112
#
# [19]	train-error:0.0696	eval-error:0.1092
#
# [20]	train-error:0.067067	eval-error:0.11
#
# [21]	train-error:0.066267	eval-error:0.1084
#
# [22]	train-error:0.063333	eval-error:0.1096
#
# [23]	train-error:0.061733	eval-error:0.1116
#
# [24]	train-error:0.0568	eval-error:0.1056
#
# [25]	train-error:0.0556	eval-error:0.1048
#
# [26]	train-error:0.0544	eval-error:0.1016
#
# [27]	train-error:0.051867	eval-error:0.1024
#
# [28]	train-error:0.0496	eval-error:0.1028
#
# [29]	train-error:0.049467	eval-error:0.1004
#
# [30]	train-error:0.0492	eval-error:0.0988
#
# [31]	train-error:0.0472	eval-error:0.102
#
# [32]	train-error:0.046	eval-error:0.0988
#
# [33]	train-error:0.0436	eval-error:0.0988
#
# [34]	train-error:0.0428	eval-error:0.1004
#
# [35]	train-error:0.042	eval-error:0.0992
#
# [36]	train-error:0.041467	eval-error:0.1016
#
# [37]	train-error:0.0388	eval-error:0.1016
#
# [38]	train-error:0.0388	eval-error:0.1016
#
# [39]	train-error:0.038533	eval-error:0.0984
#
# [40]	train-error:0.0372	eval-error:0.0984
#
# [41]	train-error:0.037333	eval-error:0.0976
#
# [42]	train-error:0.035067	eval-error:0.0964
#
# [43]	train-error:0.034133	eval-error:0.096
#
# [44]	train-error:0.033333	eval-error:0.0984
#
# [45]	train-error:0.0324	eval-error:0.0968
#
# [46]	train-error:0.031733	eval-error:0.0972
#
# [47]	train-error:0.032	eval-error:0.098
#
# [48]	train-error:0.030133	eval-error:0.0988
#
# [49]	train-error:0.030133	eval-error:0.0992
#
# params: {'gamma': 0.2, 'max_depth': 5, 'min_child_weight': 3.0}, logloss: 0.2296
# [0]	train-error:0.116	eval-error:0.1432
#
# [1]	train-error:0.104	eval-error:0.142
#
# [2]	train-error:0.096933	eval-error:0.14
#
# [3]	train-error:0.089733	eval-error:0.136
#
# [4]	train-error:0.0852	eval-error:0.1268
#
# [5]	train-error:0.077733	eval-error:0.1248
#
# [6]	train-error:0.072533	eval-error:0.1224
#
# [7]	train-error:0.0672	eval-error:0.1176
#
# [8]	train-error:0.0616	eval-error:0.1116
#
# [9]	train-error:0.057733	eval-error:0.1132
#
#  30%|██████████████▍                                 | 3/10 [00:01<00:03,  1.80trial/s, best loss: 0.22007550967978315]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [10]	train-error:0.0532	eval-error:0.1112
#
# [11]	train-error:0.051067	eval-error:0.114
#
# [12]	train-error:0.0456	eval-error:0.1092
#
# [13]	train-error:0.042133	eval-error:0.1092
#
# [14]	train-error:0.038533	eval-error:0.1136
#
# [15]	train-error:0.0348	eval-error:0.112
#
# [16]	train-error:0.029867	eval-error:0.1128
#
# [17]	train-error:0.029333	eval-error:0.112
#
# [18]	train-error:0.026533	eval-error:0.1076
#
# [19]	train-error:0.025467	eval-error:0.108
#
# [20]	train-error:0.024133	eval-error:0.108
#
# [21]	train-error:0.0208	eval-error:0.1084
#
# [22]	train-error:0.018533	eval-error:0.1084
#
# [23]	train-error:0.0176	eval-error:0.1084
#
# [24]	train-error:0.015467	eval-error:0.108
#
# [25]	train-error:0.013733	eval-error:0.104
#
# [26]	train-error:0.0124	eval-error:0.0992
#
# [27]	train-error:0.0116	eval-error:0.0984
#
# [28]	train-error:0.0104	eval-error:0.0988
#
# [29]	train-error:0.009867	eval-error:0.1
#
# [30]	train-error:0.008133	eval-error:0.0988
#
# [31]	train-error:0.006933	eval-error:0.0992
#
# [32]	train-error:0.006533	eval-error:0.0968
#
# [33]	train-error:0.006133	eval-error:0.0996
#
# [34]	train-error:0.005867	eval-error:0.1004
#
# [35]	train-error:0.005067	eval-error:0.0996
#
# [36]	train-error:0.004	eval-error:0.0992
#
# [37]	train-error:0.0036	eval-error:0.098
#
# [38]	train-error:0.0036	eval-error:0.0972
#
# [39]	train-error:0.0032	eval-error:0.0984
#
# [40]	train-error:0.003067	eval-error:0.096
#
# [41]	train-error:0.002933	eval-error:0.096
#
# [42]	train-error:0.002133	eval-error:0.0976
#
# [43]	train-error:0.001467	eval-error:0.0972
#
# [44]	train-error:0.001733	eval-error:0.0976
#
# [45]	train-error:0.001467	eval-error:0.0956
#
# [46]	train-error:0.000933	eval-error:0.0956
#
# [47]	train-error:0.000933	eval-error:0.096
#
# [48]	train-error:0.000667	eval-error:0.0944
#
# [49]	train-error:0.000667	eval-error:0.0964
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 8, 'min_child_weight': 3.0}, logloss: 0.2236
# [0]	train-error:0.154	eval-error:0.1624
#
# [1]	train-error:0.1476	eval-error:0.1604
#
# [2]	train-error:0.138533	eval-error:0.1512
#
# [3]	train-error:0.1416	eval-error:0.1516
#
# [4]	train-error:0.1348	eval-error:0.1456
#
# [5]	train-error:0.129867	eval-error:0.1428
#
# [6]	train-error:0.1272	eval-error:0.1404
#
# [7]	train-error:0.122267	eval-error:0.1424
#
# [8]	train-error:0.118933	eval-error:0.136
#
# [9]	train-error:0.115867	eval-error:0.1324
#
# [10]	train-error:0.110667	eval-error:0.1348
#
# [11]	train-error:0.106933	eval-error:0.1284
#
# [12]	train-error:0.106933	eval-error:0.1276
#
# [13]	train-error:0.103733	eval-error:0.1244
#
# [14]	train-error:0.098533	eval-error:0.12
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [15]	train-error:0.096667	eval-error:0.12
#
# [16]	train-error:0.094133	eval-error:0.1196
#
# [17]	train-error:0.093467	eval-error:0.1192
#
# [18]	train-error:0.0908	eval-error:0.1208
#
# [19]	train-error:0.088533	eval-error:0.1188
#
# [20]	train-error:0.084533	eval-error:0.12
#
# [21]	train-error:0.082667	eval-error:0.1196
#
# [22]	train-error:0.078667	eval-error:0.1164
#
# [23]	train-error:0.077867	eval-error:0.114
#
# [24]	train-error:0.0752	eval-error:0.1144
#
# [25]	train-error:0.0752	eval-error:0.1148
#
# [26]	train-error:0.072933	eval-error:0.1124
#
# [27]	train-error:0.072	eval-error:0.112
#
# [28]	train-error:0.070533	eval-error:0.1084
#
# [29]	train-error:0.068133	eval-error:0.1064
#
# [30]	train-error:0.068133	eval-error:0.1076
#
# [31]	train-error:0.064667	eval-error:0.106
#
# [32]	train-error:0.0636	eval-error:0.1068
#
# [33]	train-error:0.062667	eval-error:0.1048
#
# [34]	train-error:0.062	eval-error:0.1024
#
# [35]	train-error:0.06	eval-error:0.1044
#
# [36]	train-error:0.0596	eval-error:0.1036
#
# [37]	train-error:0.058667	eval-error:0.1008
#
# [38]	train-error:0.057867	eval-error:0.1004
#
# [39]	train-error:0.0576	eval-error:0.1004
#
# [40]	train-error:0.0564	eval-error:0.1012
#
# [41]	train-error:0.055333	eval-error:0.1
#
# [42]	train-error:0.054267	eval-error:0.1004
#
# [43]	train-error:0.0544	eval-error:0.1008
#
# [44]	train-error:0.052133	eval-error:0.1004
#
# [45]	train-error:0.051067	eval-error:0.098
#
# [46]	train-error:0.050267	eval-error:0.098
#
# [47]	train-error:0.05	eval-error:0.0992
#
# [48]	train-error:0.048267	eval-error:0.0992
#
# [49]	train-error:0.048133	eval-error:0.0976
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 4, 'min_child_weight': 3.0}, logloss: 0.2283
# [0]	train-error:0.098133	eval-error:0.1408
#
# [1]	train-error:0.0844	eval-error:0.1432
#
# [2]	train-error:0.071067	eval-error:0.1336
#
# [3]	train-error:0.0648	eval-error:0.1344
#
# [4]	train-error:0.059467	eval-error:0.1336
#
# [5]	train-error:0.051067	eval-error:0.1248
#
# [6]	train-error:0.046133	eval-error:0.1276
#
# [7]	train-error:0.040267	eval-error:0.1212
#
# [8]	train-error:0.035333	eval-error:0.1196
#
# [9]	train-error:0.029333	eval-error:0.1192
#
#  50%|████████████████████████                        | 5/10 [00:03<00:02,  1.70trial/s, best loss: 0.22007550967978315]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [10]	train-error:0.0256	eval-error:0.1184
#
# [11]	train-error:0.024267	eval-error:0.1156
#
# [12]	train-error:0.02	eval-error:0.1124
#
# [13]	train-error:0.0184	eval-error:0.1116
#
# [14]	train-error:0.0152	eval-error:0.1088
#
# [15]	train-error:0.012933	eval-error:0.1096
#
# [16]	train-error:0.0124	eval-error:0.11
#
# [17]	train-error:0.010133	eval-error:0.1084
#
# [18]	train-error:0.0088	eval-error:0.1084
#
# [19]	train-error:0.0068	eval-error:0.104
#
# [20]	train-error:0.006	eval-error:0.1056
#
# [21]	train-error:0.0048	eval-error:0.1056
#
# [22]	train-error:0.003733	eval-error:0.1056
#
# [23]	train-error:0.0036	eval-error:0.1068
#
# [24]	train-error:0.002933	eval-error:0.106
#
# [25]	train-error:0.002933	eval-error:0.1068
#
# [26]	train-error:0.002533	eval-error:0.106
#
# [27]	train-error:0.002	eval-error:0.1056
#
# [28]	train-error:0.001467	eval-error:0.1044
#
# [29]	train-error:0.001333	eval-error:0.1036
#
# [30]	train-error:0.001067	eval-error:0.1
#
# [31]	train-error:0.0008	eval-error:0.1024
#
# [32]	train-error:0.000667	eval-error:0.102
#
# [33]	train-error:0.000267	eval-error:0.1016
#
# [34]	train-error:0.000267	eval-error:0.1024
#
# [35]	train-error:0.000133	eval-error:0.1016
#
# [36]	train-error:0.000133	eval-error:0.1004
#
# [37]	train-error:0.000133	eval-error:0.098
#
# [38]	train-error:0.000133	eval-error:0.0996
#
# [39]	train-error:0	eval-error:0.0996
#
# [40]	train-error:0.000133	eval-error:0.1004
#
# [41]	train-error:0.000133	eval-error:0.0992
#
# [42]	train-error:0.000133	eval-error:0.0992
#
# [43]	train-error:0.000133	eval-error:0.0972
#
# [44]	train-error:0	eval-error:0.0976
#
# [45]	train-error:0	eval-error:0.0996
#
# [46]	train-error:0	eval-error:0.0988
#
# [47]	train-error:0	eval-error:0.0984
#
# [48]	train-error:0	eval-error:0.0984
#
# [49]	train-error:0	eval-error:0.0968
#
# params: {'gamma': 0.1, 'max_depth': 9, 'min_child_weight': 1.0}, logloss: 0.2403
# [0]	train-error:0.106133	eval-error:0.144
#
# [1]	train-error:0.090933	eval-error:0.1428
#
# [2]	train-error:0.080133	eval-error:0.1384
#
# [3]	train-error:0.074667	eval-error:0.1332
#
# [4]	train-error:0.068667	eval-error:0.1292
#
# [5]	train-error:0.062133	eval-error:0.13
#
# [6]	train-error:0.053867	eval-error:0.1272
#
# [7]	train-error:0.0492	eval-error:0.1236
#
# [8]	train-error:0.0436	eval-error:0.1204
#
# [9]	train-error:0.038	eval-error:0.12
#
# [10]	train-error:0.034	eval-error:0.1148
#
#  60%|████████████████████████████▊                   | 6/10 [00:03<00:02,  1.52trial/s, best loss: 0.22007550967978315]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [11]	train-error:0.0304	eval-error:0.1156
#
# [12]	train-error:0.026533	eval-error:0.1136
#
# [13]	train-error:0.0232	eval-error:0.1144
#
# [14]	train-error:0.0204	eval-error:0.1112
#
# [15]	train-error:0.0196	eval-error:0.112
#
# [16]	train-error:0.017467	eval-error:0.1092
#
# [17]	train-error:0.0152	eval-error:0.11
#
# [18]	train-error:0.012	eval-error:0.1088
#
# [19]	train-error:0.010533	eval-error:0.1088
#
# [20]	train-error:0.009067	eval-error:0.108
#
# [21]	train-error:0.0084	eval-error:0.1076
#
# [22]	train-error:0.007067	eval-error:0.106
#
# [23]	train-error:0.005467	eval-error:0.104
#
# [24]	train-error:0.0056	eval-error:0.1024
#
# [25]	train-error:0.004667	eval-error:0.1032
#
# [26]	train-error:0.004533	eval-error:0.1044
#
# [27]	train-error:0.0032	eval-error:0.1036
#
# [28]	train-error:0.002533	eval-error:0.1032
#
# [29]	train-error:0.0024	eval-error:0.1008
#
# [30]	train-error:0.002267	eval-error:0.1012
#
# [31]	train-error:0.001733	eval-error:0.1004
#
# [32]	train-error:0.001467	eval-error:0.1016
#
# [33]	train-error:0.001067	eval-error:0.1
#
# [34]	train-error:0.000667	eval-error:0.1
#
# [35]	train-error:0.000667	eval-error:0.1008
#
# [36]	train-error:0.000533	eval-error:0.0996
#
# [37]	train-error:0.0004	eval-error:0.0976
#
# [38]	train-error:0.000267	eval-error:0.1012
#
# [39]	train-error:0.0004	eval-error:0.0988
#
# [40]	train-error:0.0004	eval-error:0.0972
#
# [41]	train-error:0.0004	eval-error:0.0972
#
# [42]	train-error:0.0004	eval-error:0.098
#
# [43]	train-error:0	eval-error:0.0996
#
# [44]	train-error:0.000133	eval-error:0.0996
#
# [45]	train-error:0	eval-error:0.0956
#
# [46]	train-error:0	eval-error:0.096
#
# [47]	train-error:0	eval-error:0.0972
#
# [48]	train-error:0.000133	eval-error:0.0968
#
# [49]	train-error:0	eval-error:0.0964
#
# params: {'gamma': 0.0, 'max_depth': 9, 'min_child_weight': 2.0}, logloss: 0.2350
# [0]	train-error:0.142133	eval-error:0.1564
#
# [1]	train-error:0.134533	eval-error:0.1516
#
# [2]	train-error:0.1268	eval-error:0.1452
#
# [3]	train-error:0.123467	eval-error:0.1424
#
# [4]	train-error:0.115867	eval-error:0.138
#
# [5]	train-error:0.1132	eval-error:0.1372
#
# [6]	train-error:0.1096	eval-error:0.1396
#
# [7]	train-error:0.104533	eval-error:0.1352
#
# [8]	train-error:0.100667	eval-error:0.134
#
# [9]	train-error:0.098267	eval-error:0.1272
#
# [10]	train-error:0.091467	eval-error:0.1264
#
# [11]	train-error:0.088133	eval-error:0.1212
#
# [12]	train-error:0.084667	eval-error:0.1232
#
# [13]	train-error:0.081067	eval-error:0.1212
#
# [14]	train-error:0.0792	eval-error:0.1176
#
#  70%|█████████████████████████████████▌              | 7/10 [00:04<00:02,  1.45trial/s, best loss: 0.22007550967978315]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [15]	train-error:0.0772	eval-error:0.116
#
# [16]	train-error:0.075067	eval-error:0.1136
#
# [17]	train-error:0.073067	eval-error:0.1108
#
# [18]	train-error:0.069733	eval-error:0.112
#
# [19]	train-error:0.069733	eval-error:0.1092
#
# [20]	train-error:0.0672	eval-error:0.11
#
# [21]	train-error:0.066267	eval-error:0.1084
#
# [22]	train-error:0.0636	eval-error:0.1096
#
# ...
#
# [28]	train-error:0.049733	eval-error:0.1028
#
# [29]	train-error:0.049467	eval-error:0.1
#
# [30]	train-error:0.047867	eval-error:0.0992
#
# [31]	train-error:0.047467	eval-error:0.0988
#
# [32]	train-error:0.042933	eval-error:0.0972
#
# [33]	train-error:0.042133	eval-error:0.0968
#
# [34]	train-error:0.041333	eval-error:0.0984
#
# [35]	train-error:0.040933	eval-error:0.1008
#
# [36]	train-error:0.039467	eval-error:0.1004
#
# [37]	train-error:0.038533	eval-error:0.0996
#
# [38]	train-error:0.0368	eval-error:0.0968
#
# [39]	train-error:0.035733	eval-error:0.0952
#
# [40]	train-error:0.035067	eval-error:0.0948
#
# [41]	train-error:0.034267	eval-error:0.0972
#
# [42]	train-error:0.033467	eval-error:0.0936
#
# [43]	train-error:0.032	eval-error:0.0916
#
# [44]	train-error:0.031467	eval-error:0.0924
#
# [45]	train-error:0.029733	eval-error:0.0916
#
# [46]	train-error:0.0292	eval-error:0.092
#
# [47]	train-error:0.027467	eval-error:0.0928
#
# [48]	train-error:0.028	eval-error:0.0924
#
# [49]	train-error:0.028267	eval-error:0.0948
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 5, 'min_child_weight': 3.0}, logloss: 0.2211
# [0]	train-error:0.1408	eval-error:0.1572
#
# [1]	train-error:0.133733	eval-error:0.1532
#
# [2]	train-error:0.125867	eval-error:0.1504
#
# [3]	train-error:0.1212	eval-error:0.1444
#
# [4]	train-error:0.1172	eval-error:0.142
#
# [5]	train-error:0.1112	eval-error:0.1388
#
# [6]	train-error:0.1076	eval-error:0.1384
#
# [7]	train-error:0.102533	eval-error:0.128
#
# [8]	train-error:0.0948	eval-error:0.1252
#
# [9]	train-error:0.092667	eval-error:0.1268
#
# [10]	train-error:0.090533	eval-error:0.122
#
# [11]	train-error:0.085467	eval-error:0.1212
#
# [12]	train-error:0.082267	eval-error:0.1184
#
# [13]	train-error:0.0804	eval-error:0.1172
#
# [14]	train-error:0.076533	eval-error:0.1188
#
# [15]	train-error:0.072133	eval-error:0.1124
#
#  80%|██████████████████████████████████████▍         | 8/10 [00:05<00:01,  1.52trial/s, best loss: 0.22007550967978315]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [16]	train-error:0.069733	eval-error:0.11
#
# [17]	train-error:0.0692	eval-error:0.1088
#
# [18]	train-error:0.0664	eval-error:0.1024
#
# [19]	train-error:0.064	eval-error:0.1036
#
# [20]	train-error:0.062133	eval-error:0.1028
#
# [21]	train-error:0.059733	eval-error:0.1024
#
# [22]	train-error:0.055867	eval-error:0.1012
#
# [23]	train-error:0.055333	eval-error:0.102
#
# [24]	train-error:0.053733	eval-error:0.1028
#
# [25]	train-error:0.051333	eval-error:0.1012
#
# [26]	train-error:0.048533	eval-error:0.0996
#
# [27]	train-error:0.048667	eval-error:0.1008
#
# [28]	train-error:0.0476	eval-error:0.0992
#
# [29]	train-error:0.045733	eval-error:0.0988
#
# [30]	train-error:0.043867	eval-error:0.0992
#
# [31]	train-error:0.0436	eval-error:0.1
#
# [32]	train-error:0.041733	eval-error:0.1004
#
# [33]	train-error:0.041333	eval-error:0.1
#
# [34]	train-error:0.039067	eval-error:0.1008
#
# [35]	train-error:0.038533	eval-error:0.0988
#
# [36]	train-error:0.037733	eval-error:0.0964
#
# [37]	train-error:0.0368	eval-error:0.0956
#
# [38]	train-error:0.0364	eval-error:0.0956
#
# [39]	train-error:0.035333	eval-error:0.096
#
# [40]	train-error:0.033333	eval-error:0.0932
#
# [41]	train-error:0.032933	eval-error:0.0948
#
# [42]	train-error:0.030933	eval-error:0.0936
#
# [43]	train-error:0.0308	eval-error:0.0972
#
# [44]	train-error:0.0296	eval-error:0.0944
#
# [45]	train-error:0.027733	eval-error:0.0952
#
# [46]	train-error:0.027333	eval-error:0.0956
#
# [47]	train-error:0.025733	eval-error:0.0968
#
# [48]	train-error:0.0256	eval-error:0.0976
#
# [49]	train-error:0.025467	eval-error:0.098
#
# params: {'gamma': 0.4, 'max_depth': 5, 'min_child_weight': 1.0}, logloss: 0.2245
# [0]	train-error:0.106133	eval-error:0.144
#
# [1]	train-error:0.090933	eval-error:0.1428
#
# [2]	train-error:0.080133	eval-error:0.1384
#
# [3]	train-error:0.074667	eval-error:0.1332
#
# [4]	train-error:0.068667	eval-error:0.1292
#
# [5]	train-error:0.062133	eval-error:0.13
#
# [6]	train-error:0.053867	eval-error:0.1272
#
# [7]	train-error:0.0492	eval-error:0.1236
#
# [8]	train-error:0.0436	eval-error:0.1204
#
# [9]	train-error:0.038	eval-error:0.12
#
#  90%|███████████████████████████████████████████▏    | 9/10 [00:05<00:00,  1.58trial/s, best loss: 0.22007550967978315]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [10]	train-error:0.034	eval-error:0.1148
#
# [11]	train-error:0.0304	eval-error:0.1156
#
# [12]	train-error:0.026533	eval-error:0.1136
#
# [13]	train-error:0.0232	eval-error:0.1144
#
# [14]	train-error:0.0204	eval-error:0.1112
#
# [15]	train-error:0.0196	eval-error:0.112
#
# [16]	train-error:0.017467	eval-error:0.1092
#
# [17]	train-error:0.0152	eval-error:0.11
#
# [18]	train-error:0.012	eval-error:0.1088
#
# [19]	train-error:0.010533	eval-error:0.1088
#
# [20]	train-error:0.009067	eval-error:0.108
#
# [21]	train-error:0.0084	eval-error:0.1076
#
# [22]	train-error:0.007067	eval-error:0.106
#
# [23]	train-error:0.005467	eval-error:0.104
#
# [24]	train-error:0.0056	eval-error:0.1024
#
# [25]	train-error:0.004667	eval-error:0.1032
#
# [26]	train-error:0.004533	eval-error:0.1044
#
# [27]	train-error:0.0032	eval-error:0.1036
#
# [28]	train-error:0.002533	eval-error:0.1032
#
# [29]	train-error:0.0024	eval-error:0.1008
#
# [30]	train-error:0.002267	eval-error:0.1012
#
# [31]	train-error:0.001733	eval-error:0.1004
#
# [32]	train-error:0.001467	eval-error:0.1016
#
# [33]	train-error:0.001067	eval-error:0.1
#
# [34]	train-error:0.000667	eval-error:0.1
#
# [35]	train-error:0.000667	eval-error:0.1008
#
# [36]	train-error:0.000533	eval-error:0.0996
#
# [37]	train-error:0.0004	eval-error:0.0976
#
# [38]	train-error:0.000267	eval-error:0.1012
#
# [39]	train-error:0.0004	eval-error:0.0988
#
# [40]	train-error:0.0004	eval-error:0.0972
#
# [41]	train-error:0.0004	eval-error:0.0972
#
# [42]	train-error:0.0004	eval-error:0.098
#
# [43]	train-error:0	eval-error:0.0996
#
# [44]	train-error:0.000133	eval-error:0.0996
#
# [45]	train-error:0	eval-error:0.0956
#
# [46]	train-error:0	eval-error:0.096
#
# [47]	train-error:0	eval-error:0.0972
#
# [48]	train-error:0.000133	eval-error:0.0968
#
# [49]	train-error:0	eval-error:0.0964
#
# params: {'gamma': 0.0, 'max_depth': 9, 'min_child_weight': 2.0}, logloss: 0.2350
# 100%|███████████████████████████████████████████████| 10/10 [00:06<00:00,  1.55trial/s, best loss: 0.22007550967978315]
# best params:{'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 4.0}, score:0.2201

# %% [markdown]
# ### Case2-1 : Regression / predict Tokyo-housing /　target is price:　Modified by Bashii 2020-04-16

# %%
# ---------------------------------
# データ等の準備
# ----------------------------------
import numpy as np
import pandas as pd

# train_xは学習データ、train_yは目的変数
# pandasのDataFrame, Seriesで保持します。（numpyのarrayで保持することもあります）

train = pd.read_csv("housing_tokyo_chuo_line_week3.csv")
train.head()
# Out:
#        uid  years  minutes  sqrm  distance  renovate  express     price
# 0  13101-1     34        3    35  2.983801         0        0  24000000
# 1  13101-2     37        4    20  2.983801         0        0  13000000
# 2  13101-4     34        3    30  2.983801         0        0  22000000
# 3  13101-5     35        1    70  2.983801         0        0  69000000
# 4  13101-6     34        3    25  2.983801         0        0  21000000

# %%
train_x = train.iloc[: ,1:-1 ]
train_y = train['price']

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
#訓練用と検証用のindexを作成する
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# xgboostによる学習・予測を行うクラス
import xgboost as xgb


class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        #　訓練データで学習を行う
        #params = {'objective': 'binary:logistic', 'silent': 1, 'random_state': 71}
        params = {'objective':'reg:squarederror', 'silent': 1 , 'random_state': 71} #回帰の場合
        params.update(self.params) #updateメソッドで辞書型データに追加を行う。
        num_round = 50
        dtrain = xgb.DMatrix(tr_x, label=tr_y) #xgbのデータ型に変換
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# %%
# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss
from sklearn.metrics import mean_squared_error
import math


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    #score = log_loss(va_y, va_pred) # modified 04-16 
    score = np.sqrt(mean_squared_error(va_y, va_pred)) # score should be rmse 
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}

# %%
# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.quniform('min_child_weight', 1, 5, 1),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'gamma': hp.quniform('gamma', 0, 0.4, 0.1),
}

# hyperoptによるパラメータ探索の実行
max_evals = 10
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])

best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-rmse:2.94355e+07	eval-rmse:3.09964e+07
#
# [1]	train-rmse:2.18563e+07	eval-rmse:2.32619e+07
#
# [2]	train-rmse:1.65124e+07	eval-rmse:1.77919e+07
#
# [3]	train-rmse:1.29489e+07	eval-rmse:1.42494e+07
#
# [4]	train-rmse:1.05617e+07	eval-rmse:1.18998e+07
#
# [5]	train-rmse:9.0191e+06	eval-rmse:1.05371e+07
#
# [6]	train-rmse:8.00249e+06	eval-rmse:9.64646e+06
#
# [7]	train-rmse:7.36213e+06	eval-rmse:9.03612e+06
#
# [8]	train-rmse:6.9325e+06	eval-rmse:8.69412e+06
#
# [9]	train-rmse:6.6302e+06	eval-rmse:8.45757e+06
#
# [10]	train-rmse:6.4306e+06	eval-rmse:8.28887e+06
#
# [11]	train-rmse:6.2815e+06	eval-rmse:8.15705e+06
#
# [12]	train-rmse:6.15601e+06	eval-rmse:8.05085e+06
#
# [13]	train-rmse:6.06055e+06	eval-rmse:7.92019e+06
#
# [14]	train-rmse:5.99515e+06	eval-rmse:7.86968e+06
#
# [15]	train-rmse:5.91717e+06	eval-rmse:7.79584e+06
#
# [16]	train-rmse:5.87012e+06	eval-rmse:7.75735e+06
#
# [17]	train-rmse:5.80022e+06	eval-rmse:7.7042e+06
#
# [18]	train-rmse:5.74005e+06	eval-rmse:7.72853e+06
#
# [19]	train-rmse:5.70323e+06	eval-rmse:7.70043e+06
#
# [20]	train-rmse:5.66816e+06	eval-rmse:7.68419e+06
#
# [21]	train-rmse:5.62755e+06	eval-rmse:7.61524e+06
#
# [22]	train-rmse:5.59786e+06	eval-rmse:7.61513e+06
#
# [23]	train-rmse:5.58732e+06	eval-rmse:7.6194e+06
#
# [24]	train-rmse:5.57115e+06	eval-rmse:7.58579e+06
#
# [25]	train-rmse:5.53555e+06	eval-rmse:7.56894e+06
#
# [26]	train-rmse:5.50808e+06	eval-rmse:7.55855e+06
#
# [27]	train-rmse:5.48724e+06	eval-rmse:7.5612e+06
#
# [28]	train-rmse:5.46448e+06	eval-rmse:7.56011e+06
#
# [29]	train-rmse:5.43931e+06	eval-rmse:7.54382e+06
#
# [30]	train-rmse:5.41306e+06	eval-rmse:7.53205e+06
#
# [31]	train-rmse:5.39564e+06	eval-rmse:7.53452e+06
#
# [32]	train-rmse:5.3821e+06	eval-rmse:7.52224e+06
#
# [33]	train-rmse:5.37651e+06	eval-rmse:7.52232e+06
#
# [34]	train-rmse:5.35846e+06	eval-rmse:7.50786e+06
#
# [35]	train-rmse:5.35467e+06	eval-rmse:7.51084e+06
#
# [36]	train-rmse:5.34999e+06	eval-rmse:7.51688e+06
#
# [37]	train-rmse:5.31262e+06	eval-rmse:7.50035e+06
#
# [38]	train-rmse:5.28746e+06	eval-rmse:7.48228e+06
#
# [39]	train-rmse:5.23944e+06	eval-rmse:7.41896e+06
#
#   0%|                                                                           | 0/10 [00:00<?, ?trial/s, best loss=?]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [40]	train-rmse:5.19225e+06	eval-rmse:7.38418e+06
#
# [41]	train-rmse:5.18591e+06	eval-rmse:7.3662e+06
#
# [42]	train-rmse:5.17612e+06	eval-rmse:7.37158e+06
#
# [43]	train-rmse:5.16181e+06	eval-rmse:7.36881e+06
#
# [44]	train-rmse:5.15226e+06	eval-rmse:7.35815e+06
#
# [45]	train-rmse:5.13647e+06	eval-rmse:7.36238e+06
#
# [46]	train-rmse:5.13016e+06	eval-rmse:7.35519e+06
#
# [47]	train-rmse:5.1133e+06	eval-rmse:7.34928e+06
#
# [48]	train-rmse:5.08768e+06	eval-rmse:7.35499e+06
#
# [49]	train-rmse:5.07174e+06	eval-rmse:7.30841e+06
#
# params: {'gamma': 0.1, 'max_depth': 4, 'min_child_weight': 4.0}, logloss: 7308404.7811
# [0]	train-rmse:2.94355e+07	eval-rmse:3.09964e+07
#
# [1]	train-rmse:2.18563e+07	eval-rmse:2.32619e+07
#
# [2]	train-rmse:1.65124e+07	eval-rmse:1.77919e+07
#
# [3]	train-rmse:1.29489e+07	eval-rmse:1.42494e+07
#
# [4]	train-rmse:1.05617e+07	eval-rmse:1.18998e+07
#
# [5]	train-rmse:9.02262e+06	eval-rmse:1.05288e+07
#
# [6]	train-rmse:8.00008e+06	eval-rmse:9.60871e+06
#
# [7]	train-rmse:7.36354e+06	eval-rmse:9.00314e+06
#
# [8]	train-rmse:6.9407e+06	eval-rmse:8.67245e+06
#
# [9]	train-rmse:6.63011e+06	eval-rmse:8.38201e+06
#
# [10]	train-rmse:6.42817e+06	eval-rmse:8.19126e+06
#
# [11]	train-rmse:6.2774e+06	eval-rmse:8.04517e+06
#
# [12]	train-rmse:6.14913e+06	eval-rmse:7.87428e+06
#
# [13]	train-rmse:6.05445e+06	eval-rmse:7.80281e+06
#
# [14]	train-rmse:5.98586e+06	eval-rmse:7.74731e+06
#
# [15]	train-rmse:5.92779e+06	eval-rmse:7.70499e+06
#
# [16]	train-rmse:5.87486e+06	eval-rmse:7.63363e+06
#
# [17]	train-rmse:5.83236e+06	eval-rmse:7.6225e+06
#
# [18]	train-rmse:5.8019e+06	eval-rmse:7.64467e+06
#
# [19]	train-rmse:5.75188e+06	eval-rmse:7.6096e+06
#
# [20]	train-rmse:5.72116e+06	eval-rmse:7.57363e+06
#
# [21]	train-rmse:5.68758e+06	eval-rmse:7.557e+06
#
# [22]	train-rmse:5.66733e+06	eval-rmse:7.56931e+06
#
# [23]	train-rmse:5.62607e+06	eval-rmse:7.54959e+06
#
# [24]	train-rmse:5.59583e+06	eval-rmse:7.52999e+06
#
# [25]	train-rmse:5.55762e+06	eval-rmse:7.51744e+06
#
# [26]	train-rmse:5.54124e+06	eval-rmse:7.48285e+06
#
# [27]	train-rmse:5.52939e+06	eval-rmse:7.47533e+06
#
# [28]	train-rmse:5.48528e+06	eval-rmse:7.4344e+06
#
# [29]	train-rmse:5.47788e+06	eval-rmse:7.42075e+06
#
# [30]	train-rmse:5.46211e+06	eval-rmse:7.40289e+06
#
# [31]	train-rmse:5.45669e+06	eval-rmse:7.3917e+06
#
# [32]	train-rmse:5.43867e+06	eval-rmse:7.39192e+06
#
# [33]	train-rmse:5.42417e+06	eval-rmse:7.37438e+06
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [34]	train-rmse:5.39425e+06	eval-rmse:7.36763e+06
#
# [35]	train-rmse:5.37571e+06	eval-rmse:7.35825e+06
#
# [36]	train-rmse:5.37185e+06	eval-rmse:7.347e+06
#
# [37]	train-rmse:5.34848e+06	eval-rmse:7.34544e+06
#
# [38]	train-rmse:5.31707e+06	eval-rmse:7.30276e+06
#
# [39]	train-rmse:5.29708e+06	eval-rmse:7.31634e+06
#
# [40]	train-rmse:5.26102e+06	eval-rmse:7.31671e+06
#
# [41]	train-rmse:5.24064e+06	eval-rmse:7.30068e+06
#
# [42]	train-rmse:5.2226e+06	eval-rmse:7.28629e+06
#
# [43]	train-rmse:5.19155e+06	eval-rmse:7.26991e+06
#
# [44]	train-rmse:5.17351e+06	eval-rmse:7.28182e+06
#
# [45]	train-rmse:5.15835e+06	eval-rmse:7.23678e+06
#
# [46]	train-rmse:5.15664e+06	eval-rmse:7.22865e+06
#
# [47]	train-rmse:5.14184e+06	eval-rmse:7.23433e+06
#
# [48]	train-rmse:5.13018e+06	eval-rmse:7.24013e+06
#
# [49]	train-rmse:5.12674e+06	eval-rmse:7.22564e+06
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 4, 'min_child_weight': 5.0}, logloss: 7225639.5285
# [0]	train-rmse:2.94355e+07	eval-rmse:3.09964e+07
#
# [1]	train-rmse:2.18563e+07	eval-rmse:2.32619e+07
#
# [2]	train-rmse:1.65124e+07	eval-rmse:1.77919e+07
#
# [3]	train-rmse:1.29489e+07	eval-rmse:1.42494e+07
#
# [4]	train-rmse:1.05617e+07	eval-rmse:1.18998e+07
#
# [5]	train-rmse:9.0191e+06	eval-rmse:1.05371e+07
#
# [6]	train-rmse:8.00249e+06	eval-rmse:9.64646e+06
#
# [7]	train-rmse:7.36213e+06	eval-rmse:9.03612e+06
#
# [8]	train-rmse:6.9325e+06	eval-rmse:8.69412e+06
#
# [9]	train-rmse:6.6302e+06	eval-rmse:8.45757e+06
#
# [10]	train-rmse:6.4306e+06	eval-rmse:8.28887e+06
#
# [11]	train-rmse:6.2815e+06	eval-rmse:8.15705e+06
#
# [12]	train-rmse:6.15601e+06	eval-rmse:8.05085e+06
#
# [13]	train-rmse:6.06055e+06	eval-rmse:7.92019e+06
#
# [14]	train-rmse:5.99515e+06	eval-rmse:7.86968e+06
#
# [15]	train-rmse:5.91717e+06	eval-rmse:7.79584e+06
#
# [16]	train-rmse:5.87012e+06	eval-rmse:7.75735e+06
#
# [17]	train-rmse:5.80022e+06	eval-rmse:7.7042e+06
#
# [18]	train-rmse:5.74005e+06	eval-rmse:7.72853e+06
#
# [19]	train-rmse:5.70323e+06	eval-rmse:7.70043e+06
#
# [20]	train-rmse:5.66816e+06	eval-rmse:7.68419e+06
#
# [21]	train-rmse:5.62755e+06	eval-rmse:7.61524e+06
#
# [22]	train-rmse:5.59786e+06	eval-rmse:7.61513e+06
#
# [23]	train-rmse:5.58732e+06	eval-rmse:7.6194e+06
#
# [24]	train-rmse:5.57115e+06	eval-rmse:7.58579e+06
#
# [25]	train-rmse:5.53555e+06	eval-rmse:7.56894e+06
#
# [26]	train-rmse:5.50808e+06	eval-rmse:7.55855e+06
#
# [27]	train-rmse:5.48724e+06	eval-rmse:7.5612e+06
#
# [28]	train-rmse:5.46448e+06	eval-rmse:7.56011e+06
#
# [29]	train-rmse:5.43931e+06	eval-rmse:7.54382e+06
#
# [30]	train-rmse:5.41306e+06	eval-rmse:7.53205e+06
#
# [31]	train-rmse:5.39564e+06	eval-rmse:7.53452e+06
#
# [32]	train-rmse:5.3821e+06	eval-rmse:7.52224e+06
#
# [33]	train-rmse:5.37651e+06	eval-rmse:7.52232e+06
#
# [34]	train-rmse:5.35846e+06	eval-rmse:7.50786e+06
#
# [35]	train-rmse:5.35467e+06	eval-rmse:7.51084e+06
#
# [36]	train-rmse:5.34999e+06	eval-rmse:7.51688e+06
#
# [37]	train-rmse:5.31262e+06	eval-rmse:7.50035e+06
#
# [38]	train-rmse:5.28746e+06	eval-rmse:7.48228e+06
#
# [39]	train-rmse:5.23944e+06	eval-rmse:7.41896e+06
#
# [40]	train-rmse:5.19225e+06	eval-rmse:7.38418e+06
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [41]	train-rmse:5.18591e+06	eval-rmse:7.3662e+06
#
# [42]	train-rmse:5.17612e+06	eval-rmse:7.37158e+06
#
# [43]	train-rmse:5.16181e+06	eval-rmse:7.36881e+06
#
# [44]	train-rmse:5.15226e+06	eval-rmse:7.35815e+06
#
# [45]	train-rmse:5.13647e+06	eval-rmse:7.36238e+06
#
# [46]	train-rmse:5.13016e+06	eval-rmse:7.35519e+06
#
# [47]	train-rmse:5.1133e+06	eval-rmse:7.34928e+06
#
# [48]	train-rmse:5.08768e+06	eval-rmse:7.35499e+06
#
# [49]	train-rmse:5.07174e+06	eval-rmse:7.30841e+06
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 4, 'min_child_weight': 4.0}, logloss: 7308404.7811
# [0]	train-rmse:2.94355e+07	eval-rmse:3.09964e+07
#
# [1]	train-rmse:2.18563e+07	eval-rmse:2.32619e+07
#
# [2]	train-rmse:1.65124e+07	eval-rmse:1.77919e+07
#
# [3]	train-rmse:1.29489e+07	eval-rmse:1.42494e+07
#
# [4]	train-rmse:1.05585e+07	eval-rmse:1.19287e+07
#
# [5]	train-rmse:9.01698e+06	eval-rmse:1.04868e+07
#
# [6]	train-rmse:7.98878e+06	eval-rmse:9.5304e+06
#
# [7]	train-rmse:7.35371e+06	eval-rmse:8.95644e+06
#
# [8]	train-rmse:6.92724e+06	eval-rmse:8.54941e+06
#
# [9]	train-rmse:6.66068e+06	eval-rmse:8.31721e+06
#
# [10]	train-rmse:6.45946e+06	eval-rmse:8.11407e+06
#
# [11]	train-rmse:6.31178e+06	eval-rmse:7.9709e+06
#
# [12]	train-rmse:6.18399e+06	eval-rmse:7.8609e+06
#
# [13]	train-rmse:6.09309e+06	eval-rmse:7.77826e+06
#
# [14]	train-rmse:5.98762e+06	eval-rmse:7.69286e+06
#
# [15]	train-rmse:5.9092e+06	eval-rmse:7.58673e+06
#
# [16]	train-rmse:5.86376e+06	eval-rmse:7.56118e+06
#
# [17]	train-rmse:5.82334e+06	eval-rmse:7.54795e+06
#
# [18]	train-rmse:5.76501e+06	eval-rmse:7.52414e+06
#
# [19]	train-rmse:5.72436e+06	eval-rmse:7.51365e+06
#
# [20]	train-rmse:5.70593e+06	eval-rmse:7.50338e+06
#
# [21]	train-rmse:5.66724e+06	eval-rmse:7.50072e+06
#
# [22]	train-rmse:5.65918e+06	eval-rmse:7.50688e+06
#
# [23]	train-rmse:5.61474e+06	eval-rmse:7.48327e+06
#
# [24]	train-rmse:5.60272e+06	eval-rmse:7.48704e+06
#
# [25]	train-rmse:5.58781e+06	eval-rmse:7.47619e+06
#
# [26]	train-rmse:5.57368e+06	eval-rmse:7.48561e+06
#
# [27]	train-rmse:5.54061e+06	eval-rmse:7.44735e+06
#
# [28]	train-rmse:5.50296e+06	eval-rmse:7.38874e+06
#
# [29]	train-rmse:5.46837e+06	eval-rmse:7.3466e+06
#
# [30]	train-rmse:5.44254e+06	eval-rmse:7.34432e+06
#
# [31]	train-rmse:5.39642e+06	eval-rmse:7.35247e+06
#
# [32]	train-rmse:5.37033e+06	eval-rmse:7.33457e+06
#
# [33]	train-rmse:5.35206e+06	eval-rmse:7.29923e+06
#
# [34]	train-rmse:5.33309e+06	eval-rmse:7.28653e+06
#
# [35]	train-rmse:5.3264e+06	eval-rmse:7.2886e+06
#
# [36]	train-rmse:5.30963e+06	eval-rmse:7.28146e+06
#
# [37]	train-rmse:5.2967e+06	eval-rmse:7.2709e+06
#
# [38]	train-rmse:5.29172e+06	eval-rmse:7.26724e+06
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [39]	train-rmse:5.28825e+06	eval-rmse:7.25832e+06
#
# [40]	train-rmse:5.27666e+06	eval-rmse:7.25719e+06
#
# [41]	train-rmse:5.26668e+06	eval-rmse:7.23716e+06
#
# [42]	train-rmse:5.23996e+06	eval-rmse:7.23797e+06
#
# [43]	train-rmse:5.21024e+06	eval-rmse:7.23131e+06
#
# [44]	train-rmse:5.2082e+06	eval-rmse:7.23484e+06
#
# [45]	train-rmse:5.20546e+06	eval-rmse:7.23444e+06
#
# [46]	train-rmse:5.18873e+06	eval-rmse:7.24415e+06
#
# [47]	train-rmse:5.18621e+06	eval-rmse:7.25137e+06
#
# [48]	train-rmse:5.1767e+06	eval-rmse:7.25943e+06
#
# [49]	train-rmse:5.15486e+06	eval-rmse:7.25351e+06
#
# params: {'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 3.0}, logloss: 7253507.7444
# [0]	train-rmse:2.93081e+07	eval-rmse:3.08451e+07
#
# [1]	train-rmse:2.15437e+07	eval-rmse:2.29381e+07
#
# [2]	train-rmse:1.62043e+07	eval-rmse:1.76797e+07
#
# [3]	train-rmse:1.25411e+07	eval-rmse:1.40385e+07
#
# [4]	train-rmse:1.00714e+07	eval-rmse:1.17056e+07
#
# [5]	train-rmse:8.42721e+06	eval-rmse:1.02499e+07
#
# [6]	train-rmse:7.4248e+06	eval-rmse:9.33241e+06
#
# [7]	train-rmse:6.77276e+06	eval-rmse:8.69514e+06
#
# [8]	train-rmse:6.35956e+06	eval-rmse:8.31178e+06
#
# [9]	train-rmse:6.06832e+06	eval-rmse:8.05261e+06
#
# [10]	train-rmse:5.85046e+06	eval-rmse:7.77217e+06
#
# [11]	train-rmse:5.70147e+06	eval-rmse:7.6935e+06
#
# [12]	train-rmse:5.60021e+06	eval-rmse:7.57003e+06
#
# [13]	train-rmse:5.45877e+06	eval-rmse:7.40214e+06
#
# [14]	train-rmse:5.37448e+06	eval-rmse:7.37668e+06
#
# [15]	train-rmse:5.32482e+06	eval-rmse:7.34034e+06
#
# [16]	train-rmse:5.27606e+06	eval-rmse:7.33969e+06
#
# [17]	train-rmse:5.2114e+06	eval-rmse:7.29868e+06
#
# [18]	train-rmse:5.15497e+06	eval-rmse:7.28971e+06
#
# [19]	train-rmse:5.13242e+06	eval-rmse:7.31376e+06
#
# [20]	train-rmse:5.10869e+06	eval-rmse:7.31669e+06
#
# [21]	train-rmse:5.07364e+06	eval-rmse:7.2798e+06
#
# [22]	train-rmse:5.03595e+06	eval-rmse:7.27129e+06
#
# [23]	train-rmse:4.97731e+06	eval-rmse:7.27393e+06
#
# [24]	train-rmse:4.95233e+06	eval-rmse:7.29697e+06
#
# [25]	train-rmse:4.88226e+06	eval-rmse:7.2128e+06
#
# [26]	train-rmse:4.84959e+06	eval-rmse:7.1958e+06
#
# [27]	train-rmse:4.83985e+06	eval-rmse:7.16131e+06
#
# [28]	train-rmse:4.81104e+06	eval-rmse:7.14381e+06
#
# [29]	train-rmse:4.75377e+06	eval-rmse:7.10928e+06
#
# [30]	train-rmse:4.72708e+06	eval-rmse:7.09629e+06
#
# [31]	train-rmse:4.72094e+06	eval-rmse:7.08969e+06
#
# [32]	train-rmse:4.6719e+06	eval-rmse:7.07757e+06
#
# [33]	train-rmse:4.6649e+06	eval-rmse:7.08417e+06
#
# [34]	train-rmse:4.62406e+06	eval-rmse:7.02016e+06
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [35]	train-rmse:4.60736e+06	eval-rmse:7.01102e+06
#
# [36]	train-rmse:4.60138e+06	eval-rmse:7.00948e+06
#
# [37]	train-rmse:4.57916e+06	eval-rmse:7.01256e+06
#
# [38]	train-rmse:4.56168e+06	eval-rmse:7.03015e+06
#
# [39]	train-rmse:4.55093e+06	eval-rmse:7.02813e+06
#
# [40]	train-rmse:4.53538e+06	eval-rmse:7.01681e+06
#
# [41]	train-rmse:4.52167e+06	eval-rmse:7.03315e+06
#
# [42]	train-rmse:4.51673e+06	eval-rmse:7.03466e+06
#
# [43]	train-rmse:4.4997e+06	eval-rmse:7.03873e+06
#
# [44]	train-rmse:4.47168e+06	eval-rmse:7.04234e+06
#
# [45]	train-rmse:4.45961e+06	eval-rmse:7.03802e+06
#
# [46]	train-rmse:4.45493e+06	eval-rmse:7.04303e+06
#
# [47]	train-rmse:4.44732e+06	eval-rmse:7.04407e+06
#
# [48]	train-rmse:4.42751e+06	eval-rmse:7.03827e+06
#
# [49]	train-rmse:4.42078e+06	eval-rmse:7.03568e+06
#
# params: {'gamma': 0.0, 'max_depth': 5, 'min_child_weight': 4.0}, logloss: 7035681.1410
# [0]	train-rmse:2.92319e+07	eval-rmse:3.07914e+07
#
# [1]	train-rmse:2.14093e+07	eval-rmse:2.27927e+07
#
# [2]	train-rmse:1.59692e+07	eval-rmse:1.74006e+07
#
# [3]	train-rmse:1.22276e+07	eval-rmse:1.38122e+07
#
# [4]	train-rmse:9.68222e+06	eval-rmse:1.12928e+07
#
# [5]	train-rmse:8.03036e+06	eval-rmse:9.83888e+06
#
# [6]	train-rmse:6.94537e+06	eval-rmse:8.88917e+06
#
# [7]	train-rmse:6.22109e+06	eval-rmse:8.36426e+06
#
# [8]	train-rmse:5.78563e+06	eval-rmse:8.10107e+06
#
# [9]	train-rmse:5.48803e+06	eval-rmse:7.87706e+06
#
# [10]	train-rmse:5.26476e+06	eval-rmse:7.78727e+06
#
# [11]	train-rmse:5.1117e+06	eval-rmse:7.70545e+06
#
# [12]	train-rmse:4.98347e+06	eval-rmse:7.60326e+06
#
# [13]	train-rmse:4.87695e+06	eval-rmse:7.52736e+06
#
# [14]	train-rmse:4.80417e+06	eval-rmse:7.49267e+06
#
# [15]	train-rmse:4.72983e+06	eval-rmse:7.47518e+06
#
# [16]	train-rmse:4.70619e+06	eval-rmse:7.46824e+06
#
# [17]	train-rmse:4.67929e+06	eval-rmse:7.45606e+06
#
# [18]	train-rmse:4.60896e+06	eval-rmse:7.40266e+06
#
# [19]	train-rmse:4.56451e+06	eval-rmse:7.39295e+06
#
# [20]	train-rmse:4.54049e+06	eval-rmse:7.33485e+06
#
# [21]	train-rmse:4.53357e+06	eval-rmse:7.32312e+06
#
# [22]	train-rmse:4.50841e+06	eval-rmse:7.32466e+06
#
# [23]	train-rmse:4.49755e+06	eval-rmse:7.30639e+06
#
#  50%|█████████████████████████                         | 5/10 [00:01<00:01,  3.89trial/s, best loss: 7035681.141002578]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [24]	train-rmse:4.4519e+06	eval-rmse:7.3004e+06
#
# [25]	train-rmse:4.42587e+06	eval-rmse:7.28407e+06
#
# [26]	train-rmse:4.39262e+06	eval-rmse:7.27029e+06
#
# [27]	train-rmse:4.38264e+06	eval-rmse:7.27344e+06
#
# [28]	train-rmse:4.33939e+06	eval-rmse:7.25238e+06
#
# [29]	train-rmse:4.30681e+06	eval-rmse:7.23762e+06
#
# [30]	train-rmse:4.27604e+06	eval-rmse:7.17808e+06
#
# [31]	train-rmse:4.24118e+06	eval-rmse:7.15887e+06
#
# [32]	train-rmse:4.2195e+06	eval-rmse:7.12284e+06
#
# [33]	train-rmse:4.18731e+06	eval-rmse:7.10513e+06
#
# [34]	train-rmse:4.18294e+06	eval-rmse:7.10092e+06
#
# [35]	train-rmse:4.11734e+06	eval-rmse:7.09497e+06
#
# [36]	train-rmse:4.10343e+06	eval-rmse:7.10342e+06
#
# [37]	train-rmse:4.04572e+06	eval-rmse:7.09273e+06
#
# [38]	train-rmse:4.02839e+06	eval-rmse:7.08456e+06
#
# [39]	train-rmse:4.00734e+06	eval-rmse:7.08326e+06
#
# [40]	train-rmse:3.96454e+06	eval-rmse:7.06659e+06
#
# [41]	train-rmse:3.92605e+06	eval-rmse:7.08387e+06
#
# [42]	train-rmse:3.88056e+06	eval-rmse:7.09348e+06
#
# [43]	train-rmse:3.87016e+06	eval-rmse:7.06131e+06
#
# [44]	train-rmse:3.86859e+06	eval-rmse:7.0587e+06
#
# [45]	train-rmse:3.84682e+06	eval-rmse:7.06025e+06
#
# [46]	train-rmse:3.82495e+06	eval-rmse:7.07732e+06
#
# [47]	train-rmse:3.80761e+06	eval-rmse:7.05967e+06
#
# [48]	train-rmse:3.78358e+06	eval-rmse:7.07164e+06
#
# [49]	train-rmse:3.78111e+06	eval-rmse:7.06804e+06
#
# params: {'gamma': 0.1, 'max_depth': 6, 'min_child_weight': 4.0}, logloss: 7068035.4722
# [0]	train-rmse:2.91975e+07	eval-rmse:3.0749e+07
#
# [1]	train-rmse:2.13268e+07	eval-rmse:2.27438e+07
#
# [2]	train-rmse:1.58287e+07	eval-rmse:1.73019e+07
#
# [3]	train-rmse:1.20457e+07	eval-rmse:1.36317e+07
#
# [4]	train-rmse:9.46516e+06	eval-rmse:1.13433e+07
#
# [5]	train-rmse:7.76034e+06	eval-rmse:9.88331e+06
#
# [6]	train-rmse:6.61748e+06	eval-rmse:8.98715e+06
#
# [7]	train-rmse:5.8662e+06	eval-rmse:8.4253e+06
#
# [8]	train-rmse:5.37206e+06	eval-rmse:8.13608e+06
#
# [9]	train-rmse:5.03525e+06	eval-rmse:7.96782e+06
#
# [10]	train-rmse:4.78346e+06	eval-rmse:7.87816e+06
#
# [11]	train-rmse:4.62153e+06	eval-rmse:7.81285e+06
#
# [12]	train-rmse:4.51251e+06	eval-rmse:7.74233e+06
#
# [13]	train-rmse:4.41915e+06	eval-rmse:7.70951e+06
#
# [14]	train-rmse:4.31931e+06	eval-rmse:7.69587e+06
#
# [15]	train-rmse:4.229e+06	eval-rmse:7.65253e+06
#
# [16]	train-rmse:4.18253e+06	eval-rmse:7.62704e+06
#
# [17]	train-rmse:4.09389e+06	eval-rmse:7.60918e+06
#
# [18]	train-rmse:4.00004e+06	eval-rmse:7.60816e+06
#
# [19]	train-rmse:3.96573e+06	eval-rmse:7.57488e+06
#
# [20]	train-rmse:3.90944e+06	eval-rmse:7.58075e+06
#
# [21]	train-rmse:3.89758e+06	eval-rmse:7.57256e+06
#
# [22]	train-rmse:3.89047e+06	eval-rmse:7.57497e+06
#
# [23]	train-rmse:3.82412e+06	eval-rmse:7.58122e+06
#
# [24]	train-rmse:3.77263e+06	eval-rmse:7.5942e+06
#
# [25]	train-rmse:3.73686e+06	eval-rmse:7.59661e+06
#
# [26]	train-rmse:3.73185e+06	eval-rmse:7.59792e+06
#
# [27]	train-rmse:3.69314e+06	eval-rmse:7.60229e+06
#
# [28]	train-rmse:3.6643e+06	eval-rmse:7.59261e+06
#
# [29]	train-rmse:3.64272e+06	eval-rmse:7.59551e+06
#
# [30]	train-rmse:3.62674e+06	eval-rmse:7.59596e+06
#
# [31]	train-rmse:3.56798e+06	eval-rmse:7.60157e+06
#
# [32]	train-rmse:3.52688e+06	eval-rmse:7.56766e+06
#
# [33]	train-rmse:3.511e+06	eval-rmse:7.53922e+06
#
#  60%|██████████████████████████████                    | 6/10 [00:01<00:01,  3.63trial/s, best loss: 7035681.141002578]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [34]	train-rmse:3.4749e+06	eval-rmse:7.53595e+06
#
# [35]	train-rmse:3.43743e+06	eval-rmse:7.53247e+06
#
# [36]	train-rmse:3.39442e+06	eval-rmse:7.54861e+06
#
# [37]	train-rmse:3.37424e+06	eval-rmse:7.54837e+06
#
# [38]	train-rmse:3.32507e+06	eval-rmse:7.5632e+06
#
# [39]	train-rmse:3.27314e+06	eval-rmse:7.56691e+06
#
# [40]	train-rmse:3.26377e+06	eval-rmse:7.54944e+06
#
# [41]	train-rmse:3.25243e+06	eval-rmse:7.5378e+06
#
# [42]	train-rmse:3.22185e+06	eval-rmse:7.53401e+06
#
# [43]	train-rmse:3.19505e+06	eval-rmse:7.53788e+06
#
# [44]	train-rmse:3.18867e+06	eval-rmse:7.54838e+06
#
# [45]	train-rmse:3.18363e+06	eval-rmse:7.54727e+06
#
# [46]	train-rmse:3.17917e+06	eval-rmse:7.54758e+06
#
# [47]	train-rmse:3.16181e+06	eval-rmse:7.55893e+06
#
# [48]	train-rmse:3.15296e+06	eval-rmse:7.55746e+06
#
# [49]	train-rmse:3.14277e+06	eval-rmse:7.54376e+06
#
# params: {'gamma': 0.2, 'max_depth': 7, 'min_child_weight': 3.0}, logloss: 7543764.2228
# [0]	train-rmse:2.91975e+07	eval-rmse:3.07488e+07
#
# [1]	train-rmse:2.1327e+07	eval-rmse:2.2732e+07
#
# [2]	train-rmse:1.58358e+07	eval-rmse:1.72928e+07
#
# [3]	train-rmse:1.20583e+07	eval-rmse:1.36846e+07
#
# [4]	train-rmse:9.47716e+06	eval-rmse:1.14326e+07
#
# [5]	train-rmse:7.78429e+06	eval-rmse:1.00041e+07
#
# [6]	train-rmse:6.66873e+06	eval-rmse:9.13239e+06
#
# [7]	train-rmse:5.93494e+06	eval-rmse:8.52501e+06
#
# [8]	train-rmse:5.45779e+06	eval-rmse:8.21018e+06
#
# [9]	train-rmse:5.14768e+06	eval-rmse:7.99846e+06
#
# [10]	train-rmse:4.92066e+06	eval-rmse:7.88989e+06
#
# [11]	train-rmse:4.7781e+06	eval-rmse:7.79196e+06
#
# [12]	train-rmse:4.64199e+06	eval-rmse:7.71317e+06
#
# [13]	train-rmse:4.49255e+06	eval-rmse:7.66657e+06
#
# [14]	train-rmse:4.41724e+06	eval-rmse:7.63308e+06
#
# [15]	train-rmse:4.34195e+06	eval-rmse:7.54945e+06
#
# [16]	train-rmse:4.3091e+06	eval-rmse:7.56605e+06
#
# [17]	train-rmse:4.28511e+06	eval-rmse:7.55803e+06
#
# [18]	train-rmse:4.20706e+06	eval-rmse:7.55896e+06
#
# [19]	train-rmse:4.18691e+06	eval-rmse:7.56161e+06
#
# [20]	train-rmse:4.13626e+06	eval-rmse:7.54111e+06
#
# [21]	train-rmse:4.07752e+06	eval-rmse:7.53396e+06
#
# [22]	train-rmse:4.04552e+06	eval-rmse:7.52241e+06
#
# [23]	train-rmse:4.00377e+06	eval-rmse:7.52728e+06
#
# [24]	train-rmse:3.96767e+06	eval-rmse:7.52344e+06
#
# [25]	train-rmse:3.93981e+06	eval-rmse:7.51328e+06
#
# [26]	train-rmse:3.92734e+06	eval-rmse:7.51304e+06
#
# [27]	train-rmse:3.88639e+06	eval-rmse:7.52246e+06
#
# [28]	train-rmse:3.84991e+06	eval-rmse:7.53755e+06
#
# [29]	train-rmse:3.82454e+06	eval-rmse:7.51851e+06
#
# [30]	train-rmse:3.75406e+06	eval-rmse:7.51152e+06
#
#  70%|███████████████████████████████████               | 7/10 [00:02<00:00,  3.62trial/s, best loss: 7035681.141002578]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [31]	train-rmse:3.74115e+06	eval-rmse:7.48385e+06
#
# [32]	train-rmse:3.73603e+06	eval-rmse:7.48787e+06
#
# [33]	train-rmse:3.67837e+06	eval-rmse:7.47523e+06
#
# [34]	train-rmse:3.6557e+06	eval-rmse:7.47349e+06
#
# [35]	train-rmse:3.63781e+06	eval-rmse:7.48165e+06
#
# [36]	train-rmse:3.6209e+06	eval-rmse:7.46244e+06
#
# [37]	train-rmse:3.60752e+06	eval-rmse:7.4677e+06
#
# [38]	train-rmse:3.60116e+06	eval-rmse:7.46663e+06
#
# [39]	train-rmse:3.5673e+06	eval-rmse:7.46352e+06
#
# [40]	train-rmse:3.52509e+06	eval-rmse:7.46899e+06
#
# [41]	train-rmse:3.51759e+06	eval-rmse:7.47115e+06
#
# [42]	train-rmse:3.5126e+06	eval-rmse:7.47034e+06
#
# [43]	train-rmse:3.50851e+06	eval-rmse:7.47562e+06
#
# [44]	train-rmse:3.4951e+06	eval-rmse:7.46311e+06
#
# [45]	train-rmse:3.48593e+06	eval-rmse:7.46297e+06
#
# [46]	train-rmse:3.4697e+06	eval-rmse:7.46650e+06
#
# [47]	train-rmse:3.46183e+06	eval-rmse:7.46373e+06
#
# [48]	train-rmse:3.44515e+06	eval-rmse:7.46075e+06
#
# [49]	train-rmse:3.43147e+06	eval-rmse:7.44089e+06
#
# params: {'gamma': 0.2, 'max_depth': 7, 'min_child_weight': 4.0}, logloss: 7440890.4786
# [0]	train-rmse:2.94355e+07	eval-rmse:3.09964e+07
#
# [1]	train-rmse:2.18563e+07	eval-rmse:2.32619e+07
#
# [2]	train-rmse:1.65124e+07	eval-rmse:1.77919e+07
#
# [3]	train-rmse:1.29489e+07	eval-rmse:1.42494e+07
#
# [4]	train-rmse:1.05585e+07	eval-rmse:1.19287e+07
#
# [5]	train-rmse:9.01698e+06	eval-rmse:1.04868e+07
#
# [6]	train-rmse:7.98878e+06	eval-rmse:9.5304e+06
#
# [7]	train-rmse:7.35371e+06	eval-rmse:8.95644e+06
#
# [8]	train-rmse:6.92724e+06	eval-rmse:8.54941e+06
#
# [9]	train-rmse:6.66068e+06	eval-rmse:8.31721e+06
#
# [10]	train-rmse:6.45946e+06	eval-rmse:8.11407e+06
#
# [11]	train-rmse:6.31178e+06	eval-rmse:7.9709e+06
#
# [12]	train-rmse:6.18399e+06	eval-rmse:7.8609e+06
#
# [13]	train-rmse:6.09309e+06	eval-rmse:7.77826e+06
#
# [14]	train-rmse:5.98762e+06	eval-rmse:7.69286e+06
#
# [15]	train-rmse:5.9092e+06	eval-rmse:7.58673e+06
#
# [16]	train-rmse:5.86376e+06	eval-rmse:7.56118e+06
#
# [17]	train-rmse:5.82334e+06	eval-rmse:7.54795e+06
#
# [18]	train-rmse:5.76501e+06	eval-rmse:7.52414e+06
#
# [19]	train-rmse:5.72436e+06	eval-rmse:7.51365e+06
#
# [20]	train-rmse:5.70593e+06	eval-rmse:7.50338e+06
#
# [21]	train-rmse:5.66724e+06	eval-rmse:7.50072e+06
#
# [22]	train-rmse:5.65918e+06	eval-rmse:7.50688e+06
#
# [23]	train-rmse:5.61474e+06	eval-rmse:7.48327e+06
#
# [24]	train-rmse:5.60272e+06	eval-rmse:7.48704e+06
#
# [25]	train-rmse:5.58781e+06	eval-rmse:7.47619e+06
#
# [26]	train-rmse:5.57368e+06	eval-rmse:7.48561e+06
#
# [27]	train-rmse:5.54061e+06	eval-rmse:7.44735e+06
#
# [28]	train-rmse:5.50296e+06	eval-rmse:7.38874e+06
#
# [29]	train-rmse:5.46837e+06	eval-rmse:7.3466e+06
#
# [30]	train-rmse:5.44254e+06	eval-rmse:7.34432e+06
#
# [31]	train-rmse:5.39642e+06	eval-rmse:7.35247e+06
#
# [32]	train-rmse:5.37033e+06	eval-rmse:7.33457e+06
#
# [33]	train-rmse:5.35206e+06	eval-rmse:7.29923e+06
#
# [34]	train-rmse:5.33309e+06	eval-rmse:7.28653e+06
#
# [35]	train-rmse:5.3264e+06	eval-rmse:7.2886e+06
#
# [36]	train-rmse:5.30963e+06	eval-rmse:7.28146e+06
#
# [37]	train-rmse:5.2967e+06	eval-rmse:7.2709e+06
#
# [38]	train-rmse:5.29172e+06	eval-rmse:7.26724e+06
#
#  80%|████████████████████████████████████████          | 8/10 [00:02<00:00,  3.61trial/s, best loss: 7035681.141002578]
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [39]	train-rmse:5.28825e+06	eval-rmse:7.25832e+06
#
# [40]	train-rmse:5.27666e+06	eval-rmse:7.25719e+06
#
# [41]	train-rmse:5.26668e+06	eval-rmse:7.23716e+06
#
# [42]	train-rmse:5.23996e+06	eval-rmse:7.23797e+06
#
# [43]	train-rmse:5.21024e+06	eval-rmse:7.23131e+06
#
# [44]	train-rmse:5.2082e+06	eval-rmse:7.23484e+06
#
# [45]	train-rmse:5.20546e+06	eval-rmse:7.23444e+06
#
# [46]	train-rmse:5.18873e+06	eval-rmse:7.24415e+06
#
# [47]	train-rmse:5.18621e+06	eval-rmse:7.25137e+06
#
# [48]	train-rmse:5.1767e+06	eval-rmse:7.25943e+06
#
# [49]	train-rmse:5.15486e+06	eval-rmse:7.25351e+06
#
# params: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3.0}, logloss: 7253507.7444
# [0]	train-rmse:2.94355e+07	eval-rmse:3.09964e+07
#
# [1]	train-rmse:2.18563e+07	eval-rmse:2.32619e+07
#
# [2]	train-rmse:1.65124e+07	eval-rmse:1.77919e+07
#
# [3]	train-rmse:1.29489e+07	eval-rmse:1.42494e+07
#
# [4]	train-rmse:1.05617e+07	eval-rmse:1.18998e+07
#
# [5]	train-rmse:9.0191e+06	eval-rmse:1.05371e+07
#
# [6]	train-rmse:8.00249e+06	eval-rmse:9.64646e+06
#
# [7]	train-rmse:7.36213e+06	eval-rmse:9.03612e+06
#
# [8]	train-rmse:6.9325e+06	eval-rmse:8.69412e+06
#
# [9]	train-rmse:6.6302e+06	eval-rmse:8.45757e+06
#
# [10]	train-rmse:6.4306e+06	eval-rmse:8.28887e+06
#
# [11]	train-rmse:6.2815e+06	eval-rmse:8.15705e+06
#
# [12]	train-rmse:6.15601e+06	eval-rmse:8.05085e+06
#
# [13]	train-rmse:6.06055e+06	eval-rmse:7.92019e+06
#
# [14]	train-rmse:5.99515e+06	eval-rmse:7.86968e+06
#
# [15]	train-rmse:5.91717e+06	eval-rmse:7.79584e+06
#
# [16]	train-rmse:5.87012e+06	eval-rmse:7.75735e+06
#
# [17]	train-rmse:5.80022e+06	eval-rmse:7.7042e+06
#
# [18]	train-rmse:5.74005e+06	eval-rmse:7.72853e+06
#
# [19]	train-rmse:5.70323e+06	eval-rmse:7.70043e+06
#
# [20]	train-rmse:5.66816e+06	eval-rmse:7.68419e+06
#
# [21]	train-rmse:5.62755e+06	eval-rmse:7.61524e+06
#
# [22]	train-rmse:5.59786e+06	eval-rmse:7.61513e+06
#
# [23]	train-rmse:5.58732e+06	eval-rmse:7.6194e+06
#
# [24]	train-rmse:5.57115e+06	eval-rmse:7.58579e+06
#
# [25]	train-rmse:5.53555e+06	eval-rmse:7.56894e+06
#
# [26]	train-rmse:5.50808e+06	eval-rmse:7.55855e+06
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [27]	train-rmse:5.48724e+06	eval-rmse:7.5612e+06
#
# [28]	train-rmse:5.46448e+06	eval-rmse:7.56011e+06
#
# [29]	train-rmse:5.43931e+06	eval-rmse:7.54382e+06
#
# [30]	train-rmse:5.41306e+06	eval-rmse:7.53205e+06
#
# [31]	train-rmse:5.39564e+06	eval-rmse:7.53452e+06
#
# [32]	train-rmse:5.3821e+06	eval-rmse:7.52224e+06
#
# [33]	train-rmse:5.37651e+06	eval-rmse:7.52232e+06
#
# [34]	train-rmse:5.35846e+06	eval-rmse:7.50786e+06
#
# [35]	train-rmse:5.35467e+06	eval-rmse:7.51084e+06
#
# [36]	train-rmse:5.34999e+06	eval-rmse:7.51688e+06
#
# [37]	train-rmse:5.31262e+06	eval-rmse:7.50035e+06
#
# [38]	train-rmse:5.28746e+06	eval-rmse:7.48228e+06
#
# [39]	train-rmse:5.23944e+06	eval-rmse:7.41896e+06
#
# [40]	train-rmse:5.19225e+06	eval-rmse:7.38418e+06
#
# [41]	train-rmse:5.18591e+06	eval-rmse:7.3662e+06
#
# [42]	train-rmse:5.17612e+06	eval-rmse:7.37158e+06
#
# [43]	train-rmse:5.16181e+06	eval-rmse:7.36881e+06
#
# [44]	train-rmse:5.15226e+06	eval-rmse:7.35815e+06
#
# [45]	train-rmse:5.13647e+06	eval-rmse:7.36238e+06
#
# [46]	train-rmse:5.13016e+06	eval-rmse:7.35519e+06
#
# [47]	train-rmse:5.1133e+06	eval-rmse:7.34928e+06
#
# [48]	train-rmse:5.08768e+06	eval-rmse:7.35499e+06
#
# [49]	train-rmse:5.07174e+06	eval-rmse:7.30841e+06
#
# params: {'gamma': 0.1, 'max_depth': 4, 'min_child_weight': 4.0}, logloss: 7308404.7811
# 100%|█████████████████████████████████████████████████| 10/10 [00:02<00:00,  3.74trial/s, best loss: 7035681.141002578]
# best params:{'gamma': 0.0, 'max_depth': 5, 'min_child_weight': 4.0}, score:7035681.1410

# %%
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# best params:{'gamma': 0.0, 'max_depth': 5, 'min_child_weight': 4.0}, score:7035681.1410

# %%
### Best score RMSE  =  7192525.9042

# %% [markdown]
# ### Case2-2 Fixed parameter xgboost

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
#訓練用と検証用のindexを作成する
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

dtrain = xgb.DMatrix(tr_x, label=tr_y) #xgbのデータ型に変換
dvalid = xgb.DMatrix(va_x, label=va_y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \

# %%
params = {'objective':'reg:squarederror', 'silent':1 , 'random_state':71}
num_round =50
watchlist = [(dtrain,'train'),(dvalid,'eval')]

# %%
model = xgb.train(params, dtrain,num_round, evals=watchlist)
# Out:
# [0]	train-rmse:2.92318e+07	eval-rmse:3.07929e+07
# [1]	train-rmse:2.14017e+07	eval-rmse:2.2768e+07
# [2]	train-rmse:1.59455e+07	eval-rmse:1.74258e+07
# [3]	train-rmse:1.21721e+07	eval-rmse:1.36784e+07
# [4]	train-rmse:9.5989e+06	eval-rmse:1.12043e+07
# [5]	train-rmse:7.94583e+06	eval-rmse:9.78007e+06
# [6]	train-rmse:6.86056e+06	eval-rmse:8.97579e+06
# [7]	train-rmse:6.11143e+06	eval-rmse:8.4136e+06
# [8]	train-rmse:5.66383e+06	eval-rmse:8.11738e+06
# [9]	train-rmse:5.37088e+06	eval-rmse:7.91797e+06
# [10]	train-rmse:5.16083e+06	eval-rmse:7.74709e+06
# [11]	train-rmse:5.02754e+06	eval-rmse:7.69371e+06
# [12]	train-rmse:4.93783e+06	eval-rmse:7.67085e+06
# [13]	train-rmse:4.7933e+06	eval-rmse:7.65224e+06
# [14]	train-rmse:4.70651e+06	eval-rmse:7.57702e+06
# [15]	train-rmse:4.60675e+06	eval-rmse:7.55909e+06
# [16]	train-rmse:4.53352e+06	eval-rmse:7.55255e+06
# [17]	train-rmse:4.46646e+06	eval-rmse:7.53673e+06
# [18]	train-rmse:4.41877e+06	eval-rmse:7.54778e+06
# [19]	train-rmse:4.37953e+06	eval-rmse:7.51305e+06
# [20]	train-rmse:4.33164e+06	eval-rmse:7.50242e+06
# [21]	train-rmse:4.27833e+06	eval-rmse:7.47899e+06
# [22]	train-rmse:4.26484e+06	eval-rmse:7.46389e+06
# [23]	train-rmse:4.1976e+06	eval-rmse:7.4332e+06
# [24]	train-rmse:4.17812e+06	eval-rmse:7.43595e+06
# [25]	train-rmse:4.14407e+06	eval-rmse:7.42731e+06
# [26]	train-rmse:4.11873e+06	eval-rmse:7.42076e+06
# [27]	train-rmse:4.05464e+06	eval-rmse:7.42246e+06
# [28]	train-rmse:4.02929e+06	eval-rmse:7.42653e+06
# [29]	train-rmse:4.00453e+06	eval-rmse:7.43118e+06
# [30]	train-rmse:3.94952e+06	eval-rmse:7.43742e+06
# [31]	train-rmse:3.88954e+06	eval-rmse:7.42497e+06
# [32]	train-rmse:3.83615e+06	eval-rmse:7.42521e+06
# [33]	train-rmse:3.81711e+06	eval-rmse:7.41875e+06
# [34]	train-rmse:3.76444e+06	eval-rmse:7.40604e+06
# [35]	train-rmse:3.73991e+06	eval-rmse:7.39961e+06
# [36]	train-rmse:3.7041e+06	eval-rmse:7.40195e+06
# [37]	train-rmse:3.68195e+06	eval-rmse:7.38553e+06
# [38]	train-rmse:3.6556e+06	eval-rmse:7.39771e+06
# [39]	train-rmse:3.63687e+06	eval-rmse:7.39932e+06
# [40]	train-rmse:3.62641e+06	eval-rmse:7.39231e+06
# [41]	train-rmse:3.60028e+06	eval-rmse:7.36666e+06
# [42]	train-rmse:3.58295e+06	eval-rmse:7.35756e+06
# [43]	train-rmse:3.56878e+06	eval-rmse:7.34637e+06
# [44]	train-rmse:3.56491e+06	eval-rmse:7.346e+06
# [45]	train-rmse:3.53791e+06	eval-rmse:7.34573e+06
# [46]	train-rmse:3.52622e+06	eval-rmse:7.33986e+06
# [47]	train-rmse:3.5175e+06	eval-rmse:7.34126e+06
# [48]	train-rmse:3.49347e+06	eval-rmse:7.3291e+06
# [49]	train-rmse:3.44242e+06	eval-rmse:7.33062e+06

# %%
### Best score RMSE  =  7330625.00000     ( hyper-opt : 7192525.9042 )

# %% [markdown]
# ### Case 3-1 : lightgbm -> very poor rmse = 41,972,989.9949

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
#訓練用と検証用のindexを作成する
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# -----------------------------------
# lightgbmの実装
# -----------------------------------
import lightgbm as lgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をlightgbmのデータ構造に変換する
lgb_train = lgb.Dataset(tr_x, tr_y)
lgb_eval = lgb.Dataset(va_x, va_y)

# ハイパーパラメータの設定
params = {'objective': 'regression', 'seed': 71, 'verbose': 0, 'metrics': 'rmse','max_depth' : 5}
# params = {'metric': 'rmse','max_depth' : 9} # Quote from web 
num_round = 100

# 学習の実行
# カテゴリ変数をパラメータで指定している
# バリデーションデータもモデルに渡し、学習の進行とともにスコアがどう変わるかモニタリングする
#categorical_features = ['product', 'medical_info_b2', 'medical_info_b3']
model = lgb.train(params, lgb_train, num_boost_round=num_round,
                  #categorical_feature=categorical_features,
                  valid_names=['train', 'valid'], valid_sets=[lgb_train, lgb_eval])


#model = lgb.train(params,
#                lgb_train,
#                valid_sets=lgb_eval,
#                num_boost_round=10000,
#                early_stopping_rounds=100,
#                verbose_eval=50)

# バリデーションデータでのスコアの確認
va_pred = model.predict(va_x)
score = np.sqrt(mean_squared_error(va_y, va_pred)) # score should be rmse 
print(f'rmse: {score:.4f}')

# 予測#
#pred = model.predict(test_x)
# Out:
# [1]	train's rmse: 1.99253e+07	valid's rmse: 2.08145e+07
# [2]	train's rmse: 1.8397e+07	valid's rmse: 1.9357e+07
# [3]	train's rmse: 1.70462e+07	valid's rmse: 1.81049e+07
# [4]	train's rmse: 1.58082e+07	valid's rmse: 1.69065e+07
# [5]	train's rmse: 1.47116e+07	valid's rmse: 1.57885e+07
# [6]	train's rmse: 1.37086e+07	valid's rmse: 1.48291e+07
# [7]	train's rmse: 1.28342e+07	valid's rmse: 1.39542e+07
# [8]	train's rmse: 1.20143e+07	valid's rmse: 1.31459e+07
# [9]	train's rmse: 1.13204e+07	valid's rmse: 1.25095e+07
# [10]	train's rmse: 1.0709e+07	valid's rmse: 1.19486e+07
# [11]	train's rmse: 1.01556e+07	valid's rmse: 1.14441e+07
# [12]	train's rmse: 9.65342e+06	valid's rmse: 1.09688e+07
# [13]	train's rmse: 9.18699e+06	valid's rmse: 1.05277e+07
# [14]	train's rmse: 8.81142e+06	valid's rmse: 1.01851e+07
# [15]	train's rmse: 8.46774e+06	valid's rmse: 9.84986e+06
# [16]	train's rmse: 8.16015e+06	valid's rmse: 9.56064e+06
# [17]	train's rmse: 7.89006e+06	valid's rmse: 9.31167e+06
# [18]	train's rmse: 7.65666e+06	valid's rmse: 9.09594e+06
# [19]	train's rmse: 7.46349e+06	valid's rmse: 8.92154e+06
# [20]	train's rmse: 7.26293e+06	valid's rmse: 8.72442e+06
# [21]	train's rmse: 7.08974e+06	valid's rmse: 8.59149e+06
# [22]	train's rmse: 6.93818e+06	valid's rmse: 8.44602e+06
# [23]	train's rmse: 6.82713e+06	valid's rmse: 8.36131e+06
# [24]	train's rmse: 6.71484e+06	valid's rmse: 8.26855e+06
# [25]	train's rmse: 6.60464e+06	valid's rmse: 8.161e+06
# [26]	train's rmse: 6.50942e+06	valid's rmse: 8.07539e+06
# [27]	train's rmse: 6.43142e+06	valid's rmse: 7.98897e+06
# [28]	train's rmse: 6.36506e+06	valid's rmse: 7.93515e+06
# [29]	train's rmse: 6.29291e+06	valid's rmse: 7.87412e+06
# [30]	train's rmse: 6.24071e+06	valid's rmse: 7.82812e+06
# [31]	train's rmse: 6.17427e+06	valid's rmse: 7.7858e+06
# [32]	train's rmse: 6.12394e+06	valid's rmse: 7.75598e+06
# [33]	train's rmse: 6.07893e+06	valid's rmse: 7.72508e+06
# [34]	train's rmse: 6.03141e+06	valid's rmse: 7.6637e+06
# [35]	train's rmse: 5.99338e+06	valid's rmse: 7.63978e+06
# [36]	train's rmse: 5.96373e+06	valid's rmse: 7.60729e+06
# [37]	train's rmse: 5.92449e+06	valid's rmse: 7.57774e+06
# [38]	train's rmse: 5.89529e+06	valid's rmse: 7.56444e+06
# [39]	train's rmse: 5.85085e+06	valid's rmse: 7.5122e+06
# [40]	train's rmse: 5.82604e+06	valid's rmse: 7.49049e+06
# [41]	train's rmse: 5.79318e+06	valid's rmse: 7.46565e+06
# [42]	train's rmse: 5.77053e+06	valid's rmse: 7.45791e+06
# [43]	train's rmse: 5.73578e+06	valid's rmse: 7.40829e+06
# [44]	train's rmse: 5.722e+06	valid's rmse: 7.38975e+06
# [45]	train's rmse: 5.69214e+06	valid's rmse: 7.35304e+06
# [46]	train's rmse: 5.68227e+06	valid's rmse: 7.34297e+06
# [47]	train's rmse: 5.66397e+06	valid's rmse: 7.32894e+06
# [48]	train's rmse: 5.6401e+06	valid's rmse: 7.31379e+06
# [49]	train's rmse: 5.62114e+06	valid's rmse: 7.29655e+06
# [50]	train's rmse: 5.60084e+06	valid's rmse: 7.28047e+06
# [51]	train's rmse: 5.58333e+06	valid's rmse: 7.26526e+06
# [52]	train's rmse: 5.56849e+06	valid's rmse: 7.24855e+06
# [53]	train's rmse: 5.55238e+06	valid's rmse: 7.23371e+06
# [54]	train's rmse: 5.54253e+06	valid's rmse: 7.22612e+06
# [55]	train's rmse: 5.52899e+06	valid's rmse: 7.21777e+06
# [56]	train's rmse: 5.51656e+06	valid's rmse: 7.22031e+06
# [57]	train's rmse: 5.50242e+06	valid's rmse: 7.2178e+06
# [58]	train's rmse: 5.48646e+06	valid's rmse: 7.19726e+06
# [59]	train's rmse: 5.47819e+06	valid's rmse: 7.19124e+06
# [60]	train's rmse: 5.4675e+06	valid's rmse: 7.1919e+06
# [61]	train's rmse: 5.45923e+06	valid's rmse: 7.18575e+06
# [62]	train's rmse: 5.45163e+06	valid's rmse: 7.17785e+06
# [63]	train's rmse: 5.43979e+06	valid's rmse: 7.17349e+06
# [64]	train's rmse: 5.43096e+06	valid's rmse: 7.16756e+06
# [65]	train's rmse: 5.41684e+06	valid's rmse: 7.1614e+06
# [66]	train's rmse: 5.40854e+06	valid's rmse: 7.15355e+06
# [67]	train's rmse: 5.39894e+06	valid's rmse: 7.15085e+06
# [68]	train's rmse: 5.3899e+06	valid's rmse: 7.1435e+06
# [69]	train's rmse: 5.37974e+06	valid's rmse: 7.14087e+06
# [70]	train's rmse: 5.3732e+06	valid's rmse: 7.13831e+06
# [71]	train's rmse: 5.36656e+06	valid's rmse: 7.13934e+06
# [72]	train's rmse: 5.35897e+06	valid's rmse: 7.13704e+06
# [73]	train's rmse: 5.34944e+06	valid's rmse: 7.14339e+06
# [74]	train's rmse: 5.3393e+06	valid's rmse: 7.13526e+06
# [75]	train's rmse: 5.33565e+06	valid's rmse: 7.13188e+06
# [76]	train's rmse: 5.32611e+06	valid's rmse: 7.12993e+06
# [77]	train's rmse: 5.31805e+06	valid's rmse: 7.12739e+06
# [78]	train's rmse: 5.31567e+06	valid's rmse: 7.12729e+06
# [79]	train's rmse: 5.31098e+06	valid's rmse: 7.12605e+06
# [80]	train's rmse: 5.30129e+06	valid's rmse: 7.1245e+06
# [81]	train's rmse: 5.29937e+06	valid's rmse: 7.1246e+06
# [82]	train's rmse: 5.29143e+06	valid's rmse: 7.11676e+06
# [83]	train's rmse: 5.28538e+06	valid's rmse: 7.1104e+06
# [84]	train's rmse: 5.27968e+06	valid's rmse: 7.11068e+06
# [85]	train's rmse: 5.27499e+06	valid's rmse: 7.10953e+06
# [86]	train's rmse: 5.26865e+06	valid's rmse: 7.10831e+06
# [87]	train's rmse: 5.25804e+06	valid's rmse: 7.09782e+06
# [88]	train's rmse: 5.25261e+06	valid's rmse: 7.09359e+06
# [89]	train's rmse: 5.24977e+06	valid's rmse: 7.0915e+06
# [90]	train's rmse: 5.24604e+06	valid's rmse: 7.09439e+06
# [91]	train's rmse: 5.24342e+06	valid's rmse: 7.09195e+06
# [92]	train's rmse: 5.24194e+06	valid's rmse: 7.0922e+06
# [93]	train's rmse: 5.23954e+06	valid's rmse: 7.0935e+06
# [94]	train's rmse: 5.23589e+06	valid's rmse: 7.09322e+06
# [95]	train's rmse: 5.23105e+06	valid's rmse: 7.08979e+06
# [96]	train's rmse: 5.22889e+06	valid's rmse: 7.08688e+06
# [97]	train's rmse: 5.22566e+06	valid's rmse: 7.0883e+06
# [98]	train's rmse: 5.21706e+06	valid's rmse: 7.08758e+06
# [99]	train's rmse: 5.21082e+06	valid's rmse: 7.09586e+06
# [100]	train's rmse: 5.20882e+06	valid's rmse: 7.09688e+06
# rmse: 7096882.0732

# %% [markdown]
# # hyperopt and lightgbm

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
#訓練用と検証用のindexを作成する
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# xgboostによる学習・予測を行うクラス
import xgboost as xgb


class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        #　訓練データで学習を行う
        #params = {'objective': 'binary:logistic', 'silent': 1, 'random_state': 71}
        params = {'objective':'reg:squarederror', 'silent': 1 , 'random_state': 71} #回帰の場合
        params.update(self.params) #updateメソッドで辞書型データに追加を行う。
        num_round = 50
        lgb_train = lgb.Dataset(tr_x, tr_y)
        lgb_eval = lgb.Dataset(va_x, va_y)
        watchlist = [(lgb_train, 'train'), (lgb_eval, 'eval')]
        self.model = xgb.train(params, lgb_train, num_round, evals=watchlist)
        
        model = lgb.train(params, lgb_train, num_boost_round=num_round,
                  #categorical_feature=categorical_features,
                  valid_names=['train', 'valid'], valid_sets=[lgb_train, lgb_eval])

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# %%
# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss
from sklearn.metrics import mean_squared_error
import math


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    #score = log_loss(va_y, va_pred) # modified 04-16 
    score = np.sqrt(mean_squared_error(va_y, va_pred)) # score should be rmse 
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}

# %%
# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.quniform('min_child_weight', 1, 5, 1),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'gamma': hp.quniform('gamma', 0, 0.4, 0.1),
}

# hyperoptによるパラメータ探索の実行
max_evals = 10
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])

best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
#   0%|                                                                           | 0/10 [00:00<?, ?trial/s, best loss=?]
# job exception: invalid cache item: Dataset
#   0%|                                                                           | 0/10 [00:00<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-313d52f1f004> in <module>
#      10 trials = Trials()
#      11 history = []
# ---> 12 fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)
#      13
#      14 # 記録した情報からパラメータとスコアを出力する
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     480             catch_eval_exceptions=catch_eval_exceptions,
#     481             return_argmin=return_argmin,
# --> 482             show_progressbar=show_progressbar,
#     483         )
#     484
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar)
#     684             catch_eval_exceptions=catch_eval_exceptions,
#     685             return_argmin=return_argmin,
# --> 686             show_progressbar=show_progressbar,
#     687         )
#     688
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     507
#     508     # next line is where the fmin is actually executed
# --> 509     rval.exhaust()
#     510
#     511     if return_argmin:
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     328     def exhaust(self):
#     329         n_done = len(self.trials)
# --> 330         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     331         self.trials.refresh()
#     332         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     284                 else:
#     285                     # -- loop over trials and do the jobs directly
# --> 286                     self.serial_evaluate()
#     287
#     288                 self.trials.refresh()
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     163                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     164                 try:
# --> 165                     result = self.domain.evaluate(spec, ctrl)
#     166                 except Exception as e:
#     167                     logger.error("job exception: %s" % str(e))
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     892                 print_node_on_error=self.rec_eval_print_node_on_error,
#     893             )
# --> 894             rval = self.fn(pyll_rval)
#     895
#     896         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-53-420d07d69085> in score(params)
#      18     # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
#      19     model = Model(params)
# ---> 20     model.fit(tr_x, tr_y, va_x, va_y)
#      21     va_pred = model.predict(va_x)
#      22     #score = log_loss(va_y, va_pred) # modified 04-16
#
# <ipython-input-52-61fb559d5d51> in fit(self, tr_x, tr_y, va_x, va_y)
#      30         lgb_eval = lgb.Dataset(va_x, va_y)
#      31         watchlist = [(lgb_train, 'train'), (lgb_eval, 'eval')]
# ---> 32         self.model = xgb.train(params, lgb_train, num_round, evals=watchlist)
#      33
#      34         model = lgb.train(params, lgb_train, num_boost_round=num_round,
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      30             params += [('eval_metric', eval_metric)]
#      31
# ---> 32     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#      33     nboost = 0
#      34     num_parallel_tree = 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py in __init__(self, params, cache, model_file)
#     938         for d in cache:
#     939             if not isinstance(d, DMatrix):
# --> 940                 raise TypeError('invalid cache item: {}'.format(type(d).__name__))
#     941             self._validate_features(d)
#     942
#
# TypeError: invalid cache item: Dataset

# %%
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# best params:{'gamma': 0.0, 'max_depth': 5, 'min_child_weight': 4.0}, score:7035681.1410
