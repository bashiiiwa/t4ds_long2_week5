# %% [markdown]
# ####  Test hyperopt

# %% [markdown]
# ### Case.1 : 　Classification Case: Quote from "Data Analysis Technic to win at  Kaggle"

# %%
#!pip install hyperopt

# %%
# ---------------------------------
# データ等の準備
# ----------------------------------
import numpy as np
import pandas as pd

# train_xは学習データ、train_yは目的変数、test_xはテストデータ
# pandasのDataFrame, Seriesで保持します。（numpyのarrayで保持することもあります）

train = pd.read_csv('./sample-data/train_preprocessed.csv')
train_x = train.drop(['target'], axis=1)
train_y = train['target']
#test_x = pd.read_csv('./input/sample-data/test_preprocessed.csv')

# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# xgboostによる学習・予測を行うクラス
import xgboost as xgb


class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {'objective': 'binary:logistic', 'silent': 1, 'random_state': 71}
        params.update(self.params)
        num_round = 50
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.quniform('min_child_weight', 1, 5, 1),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'gamma': hp.quniform('gamma', 0, 0.4, 0.1),
}

# hyperoptによるパラメータ探索の実行
max_evals = 10
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.12107	eval-error:0.14720
#
# [1]	train-error:0.10800	eval-error:0.14160
#
# [2]	train-error:0.09747	eval-error:0.13840
#
# [3]	train-error:0.09480	eval-error:0.13640
#
# [4]	train-error:0.08987	eval-error:0.12960
#
# [5]	train-error:0.08573	eval-error:0.12960
#
# [6]	train-error:0.07827	eval-error:0.12360
#
# [7]	train-error:0.07587	eval-error:0.12240
#
# [8]	train-error:0.06880	eval-error:0.12040
#
# [9]	train-error:0.06320	eval-error:0.11840
#
# [10]	train-error:0.05733	eval-error:0.11720
#
# [11]	train-error:0.05560	eval-error:0.11680
#
# [12]	train-error:0.05040	eval-error:0.11200
#
# [13]	train-error:0.04707	eval-error:0.11280
#
# [14]	train-error:0.04520	eval-error:0.11400
#
# [15]	train-error:0.04280	eval-error:0.11160
#
# [16]	train-error:0.03840	eval-error:0.11080
#
# [17]	train-error:0.03533	eval-error:0.10640
#
# [18]	train-error:0.03467	eval-error:0.10840
#
# [19]	train-error:0.03173	eval-error:0.10360
#
# [20]	train-error:0.03013	eval-error:0.10480
#
# [21]	train-error:0.02827	eval-error:0.10480
#
# [22]	train-error:0.02480	eval-error:0.10240
#
# [23]	train-error:0.02320	eval-error:0.10400
#
# [24]	train-error:0.01920	eval-error:0.10560
#
# [25]	train-error:0.01773	eval-error:0.10320
#
# [26]	train-error:0.01760	eval-error:0.10160
#
# [27]	train-error:0.01387	eval-error:0.09680
#
# [28]	train-error:0.01320	eval-error:0.09600
#
# [29]	train-error:0.01320	eval-error:0.09640
#
# [30]	train-error:0.01200	eval-error:0.09760
#
# [31]	train-error:0.01227	eval-error:0.09720
#
# [32]	train-error:0.01067	eval-error:0.09720
#
# [33]	train-error:0.00960	eval-error:0.09600
#
# [34]	train-error:0.00853	eval-error:0.09520
#
# [35]	train-error:0.00720	eval-error:0.09720
#
# [36]	train-error:0.00640	eval-error:0.09840
#
# [37]	train-error:0.00653	eval-error:0.09880
#
# [38]	train-error:0.00653	eval-error:0.09960
#
# [39]	train-error:0.00520	eval-error:0.09880
#
# [40]	train-error:0.00507	eval-error:0.09920
#
# [41]	train-error:0.00440	eval-error:0.09760
#
# [42]	train-error:0.00467	eval-error:0.09720
#
# [43]	train-error:0.00427	eval-error:0.09480
#
# [44]	train-error:0.00400	eval-error:0.09520
#
# [45]	train-error:0.00373	eval-error:0.09440
#
# [46]	train-error:0.00413	eval-error:0.09560
#
# [47]	train-error:0.00373	eval-error:0.09400
#
# [48]	train-error:0.00333	eval-error:0.09520
#
# [49]	train-error:0.00267	eval-error:0.09600
#
# params: {'gamma': 0.2, 'max_depth': 8, 'min_child_weight': 4.0}, logloss: 0.2253
# [0]	train-error:0.15400	eval-error:0.16240
#
# [1]	train-error:0.14760	eval-error:0.16040
#
# [2]	train-error:0.13880	eval-error:0.15120
#
# [3]	train-error:0.14160	eval-error:0.15160
#
# [4]	train-error:0.13507	eval-error:0.14560
#
# [5]	train-error:0.13027	eval-error:0.14280
#
# [6]	train-error:0.12720	eval-error:0.14080
#
# [7]	train-error:0.12347	eval-error:0.14160
#
# [8]	train-error:0.11760	eval-error:0.13480
#
# [9]	train-error:0.11573	eval-error:0.13120
#
# [10]	train-error:0.11133	eval-error:0.13120
#
# [11]	train-error:0.10773	eval-error:0.13080
#
# [12]	train-error:0.10400	eval-error:0.12560
#
# [13]	train-error:0.10267	eval-error:0.12440
#
# [14]	train-error:0.09733	eval-error:0.11840
#
# [15]	train-error:0.09413	eval-error:0.11800
# [16]	train-error:0.09173	eval-error:0.11240
#
# [17]	train-error:0.09053	eval-error:0.11400
#
# [18]	train-error:0.08653	eval-error:0.11360
#
# [19]	train-error:0.08413	eval-error:0.11000
#
# [20]	train-error:0.08227	eval-error:0.11080
#
# [21]	train-error:0.08173	eval-error:0.10760
#
# [22]	train-error:0.08013	eval-error:0.10800
#
# [23]	train-error:0.07840	eval-error:0.10760
#
# [24]	train-error:0.07627	eval-error:0.10600
#
# [25]	train-error:0.07427	eval-error:0.10640
#
# [26]	train-error:0.07160	eval-error:0.10400
#
# [27]	train-error:0.07213	eval-error:0.10520
#
# [28]	train-error:0.07120	eval-error:0.10600
#
# [29]	train-error:0.06987	eval-error:0.10400
#
# [30]	train-error:0.06800	eval-error:0.10440
#
# [31]	train-error:0.06707	eval-error:0.10040
#
# [32]	train-error:0.06480	eval-error:0.10200
#
# [33]	train-error:0.06427	eval-error:0.10200
#
# [34]	train-error:0.06267	eval-error:0.10120
#
# [35]	train-error:0.06107	eval-error:0.09920
#
# [36]	train-error:0.05853	eval-error:0.09640
#
# [37]	train-error:0.05813	eval-error:0.09720
#
# [38]	train-error:0.05653	eval-error:0.09440
#
# [39]	train-error:0.05653	eval-error:0.09560
#
# [40]	train-error:0.05613	eval-error:0.09640
#
# [41]	train-error:0.05493	eval-error:0.09600
#
# [42]	train-error:0.05387	eval-error:0.09440
#
# [43]	train-error:0.05240	eval-error:0.09720
#
# [44]	train-error:0.05080	eval-error:0.09720
#
# [45]	train-error:0.05040	eval-error:0.09720
#
# [46]	train-error:0.04947	eval-error:0.09520
#
# [47]	train-error:0.04920	eval-error:0.09640
#
# [48]	train-error:0.04893	eval-error:0.09520
#
# [49]	train-error:0.04827	eval-error:0.09400
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 4, 'min_child_weight': 2.0}, logloss: 0.2312
# [0]	train-error:0.13133	eval-error:0.15440
#
# [1]	train-error:0.11973	eval-error:0.14600
#
# [2]	train-error:0.11373	eval-error:0.13800
#
# [3]	train-error:0.10760	eval-error:0.13920
#
# [4]	train-error:0.10133	eval-error:0.13640
#
# [5]	train-error:0.09987	eval-error:0.13680
#
# [6]	train-error:0.09613	eval-error:0.12880
#
# [7]	train-error:0.09147	eval-error:0.13200
#
# [8]	train-error:0.08707	eval-error:0.12840
#
# [9]	train-error:0.08027	eval-error:0.12240
#
# [10]	train-error:0.07560	eval-error:0.12280
#
# [11]	train-error:0.07200	eval-error:0.11720
#
# [12]	train-error:0.06893	eval-error:0.11360
#
# [13]	train-error:0.06507	eval-error:0.11360
#
# [14]	train-error:0.06267	eval-error:0.11320
#
# [15]	train-error:0.06040	eval-error:0.11040
#
# [16]	train-error:0.05667	eval-error:0.11000
#
# [17]	train-error:0.05507	eval-error:0.11080
#
# [18]	train-error:0.05293	eval-error:0.11320
#
# [19]	train-error:0.05240	eval-error:0.11200
#
# [20]	train-error:0.04827	eval-error:0.11040
#
# [21]	train-error:0.04493	eval-error:0.10880
#
# [22]	train-error:0.04400	eval-error:0.11080
#
# [23]	train-error:0.04413	eval-error:0.11360
#
# [24]	train-error:0.04133	eval-error:0.10960
#
# [25]	train-error:0.03720	eval-error:0.10640
#
# [26]	train-error:0.03680	eval-error:0.10720
#
# [27]	train-error:0.03480	eval-error:0.10640
#
# [28]	train-error:0.03320	eval-error:0.10400
#
# [29]	train-error:0.03187	eval-error:0.10360
#
# [30]	train-error:0.03107	eval-error:0.10360
#
# [31]	train-error:0.03040	eval-error:0.10400
# [32]	train-error:0.02720	eval-error:0.10040
#
# [33]	train-error:0.02733	eval-error:0.10040
#
# [34]	train-error:0.02560	eval-error:0.10120
#
# [35]	train-error:0.02493	eval-error:0.09960
#
# [36]	train-error:0.02333	eval-error:0.09880
#
# [37]	train-error:0.02307	eval-error:0.09760
#
# [38]	train-error:0.02120	eval-error:0.09840
#
# [39]	train-error:0.02147	eval-error:0.09920
#
# [40]	train-error:0.02040	eval-error:0.09840
#
# [41]	train-error:0.01853	eval-error:0.09800
#
# [42]	train-error:0.01760	eval-error:0.09960
#
# [43]	train-error:0.01587	eval-error:0.10000
#
# [44]	train-error:0.01507	eval-error:0.09840
#
# [45]	train-error:0.01413	eval-error:0.09920
#
# [46]	train-error:0.01427	eval-error:0.09800
#
# [47]	train-error:0.01467	eval-error:0.09920
#
# [48]	train-error:0.01387	eval-error:0.09880
#
# [49]	train-error:0.01227	eval-error:0.09840
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 6, 'min_child_weight': 3.0}, logloss: 0.2210
# [0]	train-error:0.14213	eval-error:0.15640
#
# [1]	train-error:0.13493	eval-error:0.15240
#
# [2]	train-error:0.12587	eval-error:0.14160
#
# [3]	train-error:0.12307	eval-error:0.14200
#
# [4]	train-error:0.11653	eval-error:0.14240
#
# [5]	train-error:0.11413	eval-error:0.14200
#
# [6]	train-error:0.11013	eval-error:0.13640
#
# [7]	train-error:0.10533	eval-error:0.13160
#
# [8]	train-error:0.10333	eval-error:0.12880
#
# [9]	train-error:0.09827	eval-error:0.12720
#
# [10]	train-error:0.09413	eval-error:0.12160
#
# [11]	train-error:0.09160	eval-error:0.12240
#
# [12]	train-error:0.08773	eval-error:0.12320
#
# [13]	train-error:0.08533	eval-error:0.12080
#
# [14]	train-error:0.08213	eval-error:0.11760
#
# [15]	train-error:0.08067	eval-error:0.11720
#
# [16]	train-error:0.07867	eval-error:0.11440
#
# [17]	train-error:0.07387	eval-error:0.11000
#
# [18]	train-error:0.06973	eval-error:0.11240
#
# [19]	train-error:0.06840	eval-error:0.11040
#
# [20]	train-error:0.06707	eval-error:0.10760
#
# [21]	train-error:0.06627	eval-error:0.10640
#
# [22]	train-error:0.06360	eval-error:0.10840
#
# [23]	train-error:0.06147	eval-error:0.10720
#
# [24]	train-error:0.06000	eval-error:0.10600
#
# [25]	train-error:0.05707	eval-error:0.10560
#
# [26]	train-error:0.05613	eval-error:0.10520
#
# [27]	train-error:0.05413	eval-error:0.10440
#
# [28]	train-error:0.05253	eval-error:0.10280
#
# [29]	train-error:0.04987	eval-error:0.10360
#
# [30]	train-error:0.04773	eval-error:0.10160
#
# [31]	train-error:0.04587	eval-error:0.10160
#
# [32]	train-error:0.04560	eval-error:0.10160
#
# [33]	train-error:0.04467	eval-error:0.09960
#
# [34]	train-error:0.04427	eval-error:0.09880
#
# [35]	train-error:0.04160	eval-error:0.10040
#
# [36]	train-error:0.04133	eval-error:0.10040
#
# [37]	train-error:0.03947	eval-error:0.09960
#
# [38]	train-error:0.03800	eval-error:0.09600
#
# [39]	train-error:0.03853	eval-error:0.09720
#
# [40]	train-error:0.03627	eval-error:0.09400
#
# [41]	train-error:0.03560	eval-error:0.09560
#
# [42]	train-error:0.03493	eval-error:0.09440
#
# [43]	train-error:0.03467	eval-error:0.09720
#
# [44]	train-error:0.03453	eval-error:0.09720
#
# [45]	train-error:0.03400	eval-error:0.09760
#
# [46]	train-error:0.03320	eval-error:0.09880
#
# [47]	train-error:0.03173	eval-error:0.09920
# [48]	train-error:0.03080	eval-error:0.09760
#
# [49]	train-error:0.02987	eval-error:0.09240
#
# params: {'gamma': 0.2, 'max_depth': 5, 'min_child_weight': 4.0}, logloss: 0.2213
# [0]	train-error:0.11147	eval-error:0.14280
#
# [1]	train-error:0.09920	eval-error:0.13960
#
# [2]	train-error:0.08840	eval-error:0.13560
#
# [3]	train-error:0.08467	eval-error:0.13120
#
# [4]	train-error:0.07627	eval-error:0.12400
#
# [5]	train-error:0.06907	eval-error:0.12000
#
# [6]	train-error:0.06400	eval-error:0.12160
#
# [7]	train-error:0.05973	eval-error:0.11480
#
# [8]	train-error:0.05213	eval-error:0.11800
#
# [9]	train-error:0.04907	eval-error:0.11200
#
# [10]	train-error:0.04467	eval-error:0.11200
#
# [11]	train-error:0.03973	eval-error:0.10960
#
# [12]	train-error:0.03493	eval-error:0.10760
#
# [13]	train-error:0.03333	eval-error:0.11160
#
# [14]	train-error:0.03013	eval-error:0.10600
#
# [15]	train-error:0.02600	eval-error:0.10000
#
# [16]	train-error:0.02347	eval-error:0.10160
#
# [17]	train-error:0.02227	eval-error:0.10000
#
# [18]	train-error:0.01907	eval-error:0.09920
#
# [19]	train-error:0.01800	eval-error:0.09920
#
# [20]	train-error:0.01640	eval-error:0.09640
#
# [21]	train-error:0.01427	eval-error:0.09600
#
# [22]	train-error:0.01280	eval-error:0.09680
#
# [23]	train-error:0.01187	eval-error:0.09760
#
# [24]	train-error:0.00960	eval-error:0.09800
#
# [25]	train-error:0.00933	eval-error:0.09800
#
# [26]	train-error:0.00800	eval-error:0.09840
#
# [27]	train-error:0.00773	eval-error:0.09640
#
# [28]	train-error:0.00667	eval-error:0.10000
#
# [29]	train-error:0.00587	eval-error:0.09720
#
# [30]	train-error:0.00533	eval-error:0.09560
#
# [31]	train-error:0.00453	eval-error:0.09600
#
# [32]	train-error:0.00387	eval-error:0.09440
#
# [33]	train-error:0.00347	eval-error:0.09160
#
# [34]	train-error:0.00280	eval-error:0.09320
#
# [35]	train-error:0.00227	eval-error:0.09120
#
# [36]	train-error:0.00213	eval-error:0.09240
#
# [37]	train-error:0.00173	eval-error:0.09280
#
# [38]	train-error:0.00173	eval-error:0.09160
#
# [39]	train-error:0.00160	eval-error:0.09160
#
# [40]	train-error:0.00160	eval-error:0.09240
#
# [41]	train-error:0.00147	eval-error:0.09200
#
# [42]	train-error:0.00120	eval-error:0.09280
#
# [43]	train-error:0.00093	eval-error:0.09400
#
# [44]	train-error:0.00067	eval-error:0.09360
#
# [45]	train-error:0.00067	eval-error:0.09240
#
# [46]	train-error:0.00080	eval-error:0.09400
#
# [47]	train-error:0.00067	eval-error:0.09360
#
# [48]	train-error:0.00053	eval-error:0.09400
#
# [49]	train-error:0.00053	eval-error:0.09440
#
# params: {'gamma': 0.1, 'max_depth': 8, 'min_child_weight': 2.0}, logloss: 0.2244
# [0]	train-error:0.10613	eval-error:0.14400
#
# [1]	train-error:0.09093	eval-error:0.14240
#
# [2]	train-error:0.08013	eval-error:0.13880
#
# [3]	train-error:0.07533	eval-error:0.13480
#
# [4]	train-error:0.07133	eval-error:0.13080
#
# [5]	train-error:0.06373	eval-error:0.12680
#
# [6]	train-error:0.05507	eval-error:0.12000
#
# [7]	train-error:0.05147	eval-error:0.11880
#
# [8]	train-error:0.04587	eval-error:0.11440
#
# [9]	train-error:0.04080	eval-error:0.11080
#
# [10]	train-error:0.03720	eval-error:0.11440
#
# [11]	train-error:0.03147	eval-error:0.11520
#
# [12]	train-error:0.02893	eval-error:0.11640
# [13]	train-error:0.02613	eval-error:0.11440
#
# [14]	train-error:0.02147	eval-error:0.11440
#
# [15]	train-error:0.01933	eval-error:0.11760
#
# [16]	train-error:0.01800	eval-error:0.11480
#
# [17]	train-error:0.01573	eval-error:0.11000
#
# [18]	train-error:0.01453	eval-error:0.11000
#
# [19]	train-error:0.01173	eval-error:0.10720
#
# [20]	train-error:0.00933	eval-error:0.10600
#
# [21]	train-error:0.00840	eval-error:0.10640
#
# [22]	train-error:0.00707	eval-error:0.10680
#
# [23]	train-error:0.00547	eval-error:0.10440
#
# [24]	train-error:0.00427	eval-error:0.10440
#
# [25]	train-error:0.00293	eval-error:0.10640
#
# [26]	train-error:0.00333	eval-error:0.10040
#
# [27]	train-error:0.00253	eval-error:0.10440
#
# [28]	train-error:0.00280	eval-error:0.10320
#
# [29]	train-error:0.00133	eval-error:0.10280
#
# [30]	train-error:0.00093	eval-error:0.10280
#
# [31]	train-error:0.00053	eval-error:0.10200
#
# [32]	train-error:0.00040	eval-error:0.10440
#
# [33]	train-error:0.00093	eval-error:0.10520
#
# [34]	train-error:0.00053	eval-error:0.10400
#
# [35]	train-error:0.00040	eval-error:0.10080
#
# [36]	train-error:0.00027	eval-error:0.10120
#
# [37]	train-error:0.00027	eval-error:0.10240
#
# [38]	train-error:0.00027	eval-error:0.10200
#
# [39]	train-error:0.00013	eval-error:0.10160
#
# [40]	train-error:0.00000	eval-error:0.10360
#
# [41]	train-error:0.00000	eval-error:0.10120
#
# [42]	train-error:0.00000	eval-error:0.10000
#
# [43]	train-error:0.00000	eval-error:0.10000
#
# [44]	train-error:0.00000	eval-error:0.10000
#
# [45]	train-error:0.00000	eval-error:0.10000
#
# [46]	train-error:0.00000	eval-error:0.10000
#
# [47]	train-error:0.00000	eval-error:0.09880
#
# [48]	train-error:0.00000	eval-error:0.09920
#
# [49]	train-error:0.00000	eval-error:0.09440
#
# params: {'gamma': 0.2, 'max_depth': 9, 'min_child_weight': 2.0}, logloss: 0.2323
# [0]	train-error:0.16200	eval-error:0.16880
#
# [1]	train-error:0.15627	eval-error:0.16720
#
# [2]	train-error:0.15627	eval-error:0.16600
#
# [3]	train-error:0.15160	eval-error:0.16400
#
# [4]	train-error:0.15240	eval-error:0.16800
#
# [5]	train-error:0.14627	eval-error:0.16040
#
# [6]	train-error:0.14107	eval-error:0.15760
#
# [7]	train-error:0.13960	eval-error:0.15560
#
# [8]	train-error:0.13907	eval-error:0.15440
#
# [9]	train-error:0.13427	eval-error:0.14880
#
# [10]	train-error:0.13267	eval-error:0.14560
#
# [11]	train-error:0.12760	eval-error:0.14160
#
# [12]	train-error:0.12387	eval-error:0.14200
#
# [13]	train-error:0.12067	eval-error:0.13920
#
# [14]	train-error:0.11733	eval-error:0.13360
#
# [15]	train-error:0.11240	eval-error:0.13200
#
# [16]	train-error:0.11080	eval-error:0.13240
#
# [17]	train-error:0.10947	eval-error:0.12720
#
# [18]	train-error:0.10600	eval-error:0.12640
#
# [19]	train-error:0.10547	eval-error:0.12640
#
# [20]	train-error:0.10173	eval-error:0.12120
#
# [21]	train-error:0.10000	eval-error:0.12080
#
# [22]	train-error:0.09800	eval-error:0.11960
#
# [23]	train-error:0.09693	eval-error:0.11600
#
# [24]	train-error:0.09627	eval-error:0.11640
#
# [25]	train-error:0.09427	eval-error:0.11640
#
# [26]	train-error:0.09307	eval-error:0.11800
#
# [27]	train-error:0.09147	eval-error:0.11320
#
# [28]	train-error:0.09040	eval-error:0.11440
# [29]	train-error:0.08920	eval-error:0.11400
#
# [30]	train-error:0.08760	eval-error:0.11240
#
# [31]	train-error:0.08613	eval-error:0.10880
#
# [32]	train-error:0.08400	eval-error:0.11160
#
# [33]	train-error:0.08320	eval-error:0.11120
#
# [34]	train-error:0.08173	eval-error:0.11160
#
# [35]	train-error:0.08227	eval-error:0.11040
#
# [36]	train-error:0.08227	eval-error:0.10920
#
# [37]	train-error:0.08107	eval-error:0.11040
#
# [38]	train-error:0.08053	eval-error:0.10840
#
# [39]	train-error:0.07893	eval-error:0.11080
#
# [40]	train-error:0.07573	eval-error:0.10560
#
# [41]	train-error:0.07480	eval-error:0.10680
#
# [42]	train-error:0.07560	eval-error:0.10680
#
# [43]	train-error:0.07427	eval-error:0.10640
#
# [44]	train-error:0.07400	eval-error:0.10360
#
# [45]	train-error:0.07240	eval-error:0.10560
#
# [46]	train-error:0.07200	eval-error:0.10640
#
# [47]	train-error:0.07147	eval-error:0.10600
#
# [48]	train-error:0.07000	eval-error:0.10560
#
# [49]	train-error:0.06933	eval-error:0.10600
#
# params: {'gamma': 0.1, 'max_depth': 3, 'min_child_weight': 2.0}, logloss: 0.2489
# [0]	train-error:0.12400	eval-error:0.14560
#
# [1]	train-error:0.11493	eval-error:0.14480
#
# [2]	train-error:0.11160	eval-error:0.14080
#
# [3]	train-error:0.10520	eval-error:0.13640
#
# [4]	train-error:0.09733	eval-error:0.13200
#
# [5]	train-error:0.09160	eval-error:0.13520
#
# [6]	train-error:0.08453	eval-error:0.12840
#
# [7]	train-error:0.08227	eval-error:0.12360
#
# [8]	train-error:0.07720	eval-error:0.12120
#
# [9]	train-error:0.07360	eval-error:0.12200
#
# [10]	train-error:0.06707	eval-error:0.11840
#
# [11]	train-error:0.06347	eval-error:0.11680
#
# [12]	train-error:0.05893	eval-error:0.11400
#
# [13]	train-error:0.05667	eval-error:0.11240
#
# [14]	train-error:0.05227	eval-error:0.11080
#
# [15]	train-error:0.05080	eval-error:0.10920
#
# [16]	train-error:0.04907	eval-error:0.10800
#
# [17]	train-error:0.04480	eval-error:0.10760
#
# [18]	train-error:0.04053	eval-error:0.10600
#
# [19]	train-error:0.03800	eval-error:0.10680
#
# [20]	train-error:0.03693	eval-error:0.10640
#
# [21]	train-error:0.03400	eval-error:0.10400
#
# [22]	train-error:0.03320	eval-error:0.10480
#
# [23]	train-error:0.03187	eval-error:0.10360
#
# [24]	train-error:0.02987	eval-error:0.10320
#
# [25]	train-error:0.02840	eval-error:0.10440
#
# [26]	train-error:0.02720	eval-error:0.10400
#
# [27]	train-error:0.02560	eval-error:0.10000
#
# [28]	train-error:0.02347	eval-error:0.09880
#
# [29]	train-error:0.02347	eval-error:0.10000
#
# [30]	train-error:0.02253	eval-error:0.09680
#
# [31]	train-error:0.02160	eval-error:0.09720
#
# [32]	train-error:0.01893	eval-error:0.09720
#
# [33]	train-error:0.01747	eval-error:0.09720
#
# [34]	train-error:0.01680	eval-error:0.09840
#
# [35]	train-error:0.01533	eval-error:0.09800
#
# [36]	train-error:0.01533	eval-error:0.09880
#
# [37]	train-error:0.01453	eval-error:0.09840
#
# [38]	train-error:0.01387	eval-error:0.09760
#
# [39]	train-error:0.01360	eval-error:0.09920
#
# [40]	train-error:0.01213	eval-error:0.10000
#
# [41]	train-error:0.01000	eval-error:0.09840
#
# [42]	train-error:0.01027	eval-error:0.09800
#
# [43]	train-error:0.00933	eval-error:0.09680
#
# [44]	train-error:0.00840	eval-error:0.09680
# [45]	train-error:0.00840	eval-error:0.09720
#
# [46]	train-error:0.00747	eval-error:0.09800
#
# [47]	train-error:0.00560	eval-error:0.09560
#
# [48]	train-error:0.00560	eval-error:0.09520
#
# [49]	train-error:0.00507	eval-error:0.09520
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 7, 'min_child_weight': 4.0}, logloss: 0.2190
# [0]	train-error:0.13000	eval-error:0.15240
#
# [1]	train-error:0.11707	eval-error:0.14560
#
# [2]	train-error:0.11333	eval-error:0.14120
#
# [3]	train-error:0.10613	eval-error:0.14200
#
# [4]	train-error:0.09853	eval-error:0.13280
#
# [5]	train-error:0.09507	eval-error:0.13360
#
# [6]	train-error:0.09107	eval-error:0.13080
#
# [7]	train-error:0.08853	eval-error:0.13240
#
# [8]	train-error:0.08307	eval-error:0.13320
#
# [9]	train-error:0.07787	eval-error:0.12480
#
# [10]	train-error:0.07480	eval-error:0.12280
#
# [11]	train-error:0.07040	eval-error:0.12000
#
# [12]	train-error:0.06720	eval-error:0.11880
#
# [13]	train-error:0.06200	eval-error:0.11480
#
# [14]	train-error:0.05867	eval-error:0.11320
#
# [15]	train-error:0.05733	eval-error:0.11080
#
# [16]	train-error:0.05600	eval-error:0.10960
#
# [17]	train-error:0.05147	eval-error:0.11000
#
# [18]	train-error:0.04920	eval-error:0.11000
#
# [19]	train-error:0.04707	eval-error:0.10680
#
# [20]	train-error:0.04200	eval-error:0.10440
#
# [21]	train-error:0.04067	eval-error:0.10520
#
# [22]	train-error:0.03747	eval-error:0.10280
#
# [23]	train-error:0.03587	eval-error:0.10240
#
# [24]	train-error:0.03467	eval-error:0.10360
#
# [25]	train-error:0.03360	eval-error:0.10400
#
# [26]	train-error:0.03160	eval-error:0.10200
#
# [27]	train-error:0.03000	eval-error:0.10400
#
# [28]	train-error:0.02827	eval-error:0.10280
#
# [29]	train-error:0.02653	eval-error:0.10120
#
# [30]	train-error:0.02587	eval-error:0.10160
#
# [31]	train-error:0.02507	eval-error:0.10240
#
# [32]	train-error:0.02413	eval-error:0.10200
#
# [33]	train-error:0.02200	eval-error:0.10320
#
# [34]	train-error:0.02053	eval-error:0.10120
#
# [35]	train-error:0.01920	eval-error:0.10080
#
# [36]	train-error:0.01867	eval-error:0.10160
#
# [37]	train-error:0.01720	eval-error:0.10240
#
# [38]	train-error:0.01693	eval-error:0.10000
#
# [39]	train-error:0.01627	eval-error:0.09920
#
# [40]	train-error:0.01507	eval-error:0.10040
#
# [41]	train-error:0.01480	eval-error:0.09840
#
# [42]	train-error:0.01360	eval-error:0.09880
#
# [43]	train-error:0.01227	eval-error:0.09880
#
# [44]	train-error:0.01107	eval-error:0.09840
#
# [45]	train-error:0.01173	eval-error:0.09800
#
# [46]	train-error:0.01147	eval-error:0.09920
#
# [47]	train-error:0.01053	eval-error:0.09840
#
# [48]	train-error:0.00987	eval-error:0.09800
#
# [49]	train-error:0.01013	eval-error:0.09840
#
# params: {'gamma': 0.1, 'max_depth': 6, 'min_child_weight': 2.0}, logloss: 0.2221
# [0]	train-error:0.15400	eval-error:0.16240
#
# [1]	train-error:0.14760	eval-error:0.16040
#
# [2]	train-error:0.13853	eval-error:0.15240
#
# [3]	train-error:0.14280	eval-error:0.15080
#
# [4]	train-error:0.13133	eval-error:0.14520
#
# [5]	train-error:0.12880	eval-error:0.14600
#
# [6]	train-error:0.12827	eval-error:0.14480
#
# [7]	train-error:0.12293	eval-error:0.14280
#
# [8]	train-error:0.11840	eval-error:0.13600
#
# [9]	train-error:0.11280	eval-error:0.13040
# [10]	train-error:0.11147	eval-error:0.13200
#
# [11]	train-error:0.10507	eval-error:0.12760
#
# [12]	train-error:0.10307	eval-error:0.12480
#
# [13]	train-error:0.10147	eval-error:0.12120
#
# [14]	train-error:0.09413	eval-error:0.12080
#
# [15]	train-error:0.09160	eval-error:0.11840
#
# [16]	train-error:0.08947	eval-error:0.11600
#
# [17]	train-error:0.08853	eval-error:0.11200
#
# [18]	train-error:0.08373	eval-error:0.11200
#
# [19]	train-error:0.08293	eval-error:0.10960
#
# [20]	train-error:0.08120	eval-error:0.10800
#
# [21]	train-error:0.08147	eval-error:0.10920
#
# [22]	train-error:0.07987	eval-error:0.11080
#
# [23]	train-error:0.07640	eval-error:0.10720
#
# [24]	train-error:0.07427	eval-error:0.11000
#
# [25]	train-error:0.07427	eval-error:0.11040
#
# [26]	train-error:0.07293	eval-error:0.10680
#
# [27]	train-error:0.07213	eval-error:0.10760
#
# [28]	train-error:0.06893	eval-error:0.10800
#
# [29]	train-error:0.06573	eval-error:0.10280
#
# [30]	train-error:0.06480	eval-error:0.10320
#
# [31]	train-error:0.06413	eval-error:0.10320
#
# [32]	train-error:0.06387	eval-error:0.10200
#
# [33]	train-error:0.06053	eval-error:0.10000
#
# [34]	train-error:0.05973	eval-error:0.10160
#
# [35]	train-error:0.05973	eval-error:0.09840
#
# [36]	train-error:0.05853	eval-error:0.09840
#
# [37]	train-error:0.05653	eval-error:0.09760
#
# [38]	train-error:0.05533	eval-error:0.09880
#
# [39]	train-error:0.05507	eval-error:0.09600
#
# [40]	train-error:0.05400	eval-error:0.09560
#
# [41]	train-error:0.05227	eval-error:0.09320
#
# [42]	train-error:0.05227	eval-error:0.09320
#
# [43]	train-error:0.05013	eval-error:0.09440
#
# [44]	train-error:0.04973	eval-error:0.09320
#
# [45]	train-error:0.04867	eval-error:0.09280
#
# [46]	train-error:0.04787	eval-error:0.09520
#
# [47]	train-error:0.04720	eval-error:0.09640
#
# [48]	train-error:0.04747	eval-error:0.09480
#
# [49]	train-error:0.04587	eval-error:0.09320
#
# params: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 4.0}, logloss: 0.2201
# 100%|███████████████████████████████████████████████| 10/10 [00:06<00:00,  1.52trial/s, best loss: 0.21898408544287667]
# best params:{'gamma': 0.30000000000000004, 'max_depth': 7, 'min_child_weight': 4.0}, score:0.2190

# %% [markdown]
# ### Case2 : Regression / predict Tokyo-housing /　target is price:　Modified by Bashii 2020-04-16

# %%
# ---------------------------------
# データ等の準備
# ----------------------------------
import numpy as np
import pandas as pd

# train_xは学習データ、train_yは目的変数
# pandasのDataFrame, Seriesで保持します。（numpyのarrayで保持することもあります）

train = pd.read_csv("housing_tokyo_chuo_line_week3.csv")
train.head()
# Out:
#        uid  years  minutes  sqrm  distance  renovate  express     price
# 0  13101-1     34        3    35  2.983801         0        0  24000000
# 1  13101-2     37        4    20  2.983801         0        0  13000000
# 2  13101-4     34        3    30  2.983801         0        0  22000000
# 3  13101-5     35        1    70  2.983801         0        0  69000000
# 4  13101-6     34        3    25  2.983801         0        0  21000000

# %%
train_x = train.iloc[: ,1:-1 ]
train_y = train['price']

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
#訓練用と検証用のindexを作成する
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# xgboostによる学習・予測を行うクラス
import xgboost as xgb


class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        #　訓練データで学習を行う
        #params = {'objective': 'binary:logistic', 'silent': 1, 'random_state': 71}
        params = {'objective':'reg:squarederror', 'silent': 1 , 'random_state': 71} #回帰の場合
        params.update(self.params) #updateメソッドで辞書型データに追加を行う。
        num_round = 50
        dtrain = xgb.DMatrix(tr_x, label=tr_y) #xgbのデータ型に変換
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# %%
# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss
from sklearn.metrics import mean_squared_error
import math


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    #score = log_loss(va_y, va_pred) # modified 04-16 
    score = np.sqrt(mean_squared_error(va_y, va_pred))　# score should be rmse 
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}

# %% [markdown]
# ### Seems OK.

# %%
# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.quniform('min_child_weight', 1, 5, 1),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'gamma': hp.quniform('gamma', 0, 0.4, 0.1),
}

# hyperoptによるパラメータ探索の実行
max_evals = 10
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])

best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-rmse:29435498.00000	eval-rmse:30996432.00000
#
# [1]	train-rmse:21856338.00000	eval-rmse:23261902.00000
#
# [2]	train-rmse:16512384.00000	eval-rmse:17791948.00000
#
# [3]	train-rmse:12948883.00000	eval-rmse:14249404.00000
#
# [4]	train-rmse:10558537.00000	eval-rmse:11928664.00000
#
# [5]	train-rmse:9016975.00000	eval-rmse:10486821.00000
#
# [6]	train-rmse:7988780.50000	eval-rmse:9530399.00000
#
# [7]	train-rmse:7353711.50000	eval-rmse:8956440.00000
#
# [8]	train-rmse:6927239.50000	eval-rmse:8549406.00000
#
# [9]	train-rmse:6660675.50000	eval-rmse:8317208.00000
#
# [10]	train-rmse:6459458.50000	eval-rmse:8114073.00000
#
# [11]	train-rmse:6311783.50000	eval-rmse:7970897.00000
#
# [12]	train-rmse:6183993.50000	eval-rmse:7860904.00000
#
# [13]	train-rmse:6093090.00000	eval-rmse:7778261.50000
#
# [14]	train-rmse:5987623.00000	eval-rmse:7692857.50000
#
# [15]	train-rmse:5909203.00000	eval-rmse:7586728.00000
#
# [16]	train-rmse:5863760.00000	eval-rmse:7561182.00000
#
# [17]	train-rmse:5823336.00000	eval-rmse:7547949.00000
#
# [18]	train-rmse:5765009.50000	eval-rmse:7524142.00000
#
# [19]	train-rmse:5724357.00000	eval-rmse:7513654.50000
#
# [20]	train-rmse:5705926.00000	eval-rmse:7503378.50000
#
# [21]	train-rmse:5667236.50000	eval-rmse:7500723.00000
#
# [22]	train-rmse:5659184.50000	eval-rmse:7506876.00000
#
# [23]	train-rmse:5614735.50000	eval-rmse:7483274.50000
#
# [24]	train-rmse:5602718.00000	eval-rmse:7487042.00000
#
# [25]	train-rmse:5587808.50000	eval-rmse:7476190.50000
#
# [26]	train-rmse:5573684.00000	eval-rmse:7485610.00000
#
# [27]	train-rmse:5540614.50000	eval-rmse:7447351.50000
#
# [28]	train-rmse:5502956.00000	eval-rmse:7388740.00000
#
# [29]	train-rmse:5468373.00000	eval-rmse:7346596.00000
#
# [30]	train-rmse:5442545.00000	eval-rmse:7344321.50000
#
# [31]	train-rmse:5396418.00000	eval-rmse:7352466.50000
#
# [32]	train-rmse:5370332.00000	eval-rmse:7334573.00000
#
# [33]	train-rmse:5352059.50000	eval-rmse:7299226.50000
#
# [34]	train-rmse:5333088.00000	eval-rmse:7286532.50000
#
# [35]	train-rmse:5326404.50000	eval-rmse:7288600.50000
#
# [36]	train-rmse:5309626.50000	eval-rmse:7281457.00000
#
# [37]	train-rmse:5296702.50000	eval-rmse:7270903.00000
#
# [38]	train-rmse:5291722.00000	eval-rmse:7267241.50000
#
# [39]	train-rmse:5288248.00000	eval-rmse:7258322.50000
#
# [40]	train-rmse:5276665.00000	eval-rmse:7257189.00000
#
# [41]	train-rmse:5266683.00000	eval-rmse:7237164.00000
#
# [42]	train-rmse:5239959.50000	eval-rmse:7237971.50000
#
# [43]	train-rmse:5210237.00000	eval-rmse:7231313.00000
#
# [44]	train-rmse:5208200.00000	eval-rmse:7234843.00000
#
# [45]	train-rmse:5205458.50000	eval-rmse:7234435.00000
#
# [46]	train-rmse:5188734.50000	eval-rmse:7244147.00000
#
# [47]	train-rmse:5186212.50000	eval-rmse:7251373.00000
#
# [48]	train-rmse:5176700.50000	eval-rmse:7259428.00000
#
# [49]	train-rmse:5154859.50000	eval-rmse:7253508.00000
#
# params: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3.0}, logloss: 7253507.7444
# [0]	train-rmse:29435498.00000	eval-rmse:30996432.00000
#
# [1]	train-rmse:21856338.00000	eval-rmse:23261902.00000
#
# [2]	train-rmse:16512384.00000	eval-rmse:17791948.00000
#
# [3]	train-rmse:12948883.00000	eval-rmse:14249404.00000
#
# [4]	train-rmse:10558537.00000	eval-rmse:11928664.00000
#
# [5]	train-rmse:9016975.00000	eval-rmse:10486821.00000
#
# [6]	train-rmse:7988780.50000	eval-rmse:9530399.00000
#
# [7]	train-rmse:7352104.00000	eval-rmse:8953148.00000
#
# [8]	train-rmse:6920363.00000	eval-rmse:8558977.00000
#
# [9]	train-rmse:6651553.00000	eval-rmse:8326787.00000
#
# [10]	train-rmse:6449618.00000	eval-rmse:8122151.00000
#
# [11]	train-rmse:6300335.50000	eval-rmse:7999301.00000
#
# [12]	train-rmse:6171485.00000	eval-rmse:7919287.50000
#
# [13]	train-rmse:6088603.50000	eval-rmse:7860885.00000
#
# [14]	train-rmse:6019950.50000	eval-rmse:7824283.50000
#
# [15]	train-rmse:5925211.00000	eval-rmse:7762475.50000
# [16]	train-rmse:5877326.00000	eval-rmse:7721957.50000
#
# [17]	train-rmse:5800356.00000	eval-rmse:7659926.00000
#
# [18]	train-rmse:5757075.50000	eval-rmse:7613188.50000
#
# [19]	train-rmse:5735687.50000	eval-rmse:7608182.50000
#
# [20]	train-rmse:5710833.00000	eval-rmse:7598942.00000
#
# [21]	train-rmse:5662755.50000	eval-rmse:7551708.00000
#
# [22]	train-rmse:5626047.00000	eval-rmse:7557417.50000
#
# [23]	train-rmse:5610692.50000	eval-rmse:7540442.00000
#
# [24]	train-rmse:5553174.50000	eval-rmse:7511809.50000
#
# [25]	train-rmse:5544875.50000	eval-rmse:7511007.00000
#
# [26]	train-rmse:5527699.00000	eval-rmse:7508893.00000
#
# [27]	train-rmse:5524363.00000	eval-rmse:7511139.50000
#
# [28]	train-rmse:5508787.00000	eval-rmse:7500924.50000
#
# [29]	train-rmse:5476304.00000	eval-rmse:7469217.50000
#
# [30]	train-rmse:5445269.50000	eval-rmse:7470750.50000
#
# [31]	train-rmse:5408212.50000	eval-rmse:7458581.00000
#
# [32]	train-rmse:5398603.00000	eval-rmse:7434206.00000
#
# [33]	train-rmse:5394255.50000	eval-rmse:7432154.50000
#
# [34]	train-rmse:5379892.00000	eval-rmse:7424236.50000
#
# [35]	train-rmse:5353957.50000	eval-rmse:7435697.00000
#
# [36]	train-rmse:5311816.00000	eval-rmse:7435247.50000
#
# [37]	train-rmse:5302496.00000	eval-rmse:7429506.00000
#
# [38]	train-rmse:5264122.50000	eval-rmse:7410988.00000
#
# [39]	train-rmse:5262329.00000	eval-rmse:7410034.00000
#
# [40]	train-rmse:5256746.50000	eval-rmse:7408727.50000
#
# [41]	train-rmse:5221744.50000	eval-rmse:7395847.00000
#
# [42]	train-rmse:5207379.00000	eval-rmse:7396870.50000
#
# [43]	train-rmse:5170717.50000	eval-rmse:7418110.50000
#
# [44]	train-rmse:5147778.00000	eval-rmse:7418704.50000
#
# [45]	train-rmse:5145911.00000	eval-rmse:7418689.00000
#
# [46]	train-rmse:5113412.00000	eval-rmse:7409576.00000
#
# [47]	train-rmse:5112052.50000	eval-rmse:7407756.00000
#
# [48]	train-rmse:5095298.50000	eval-rmse:7390682.50000
#
# [49]	train-rmse:5077884.00000	eval-rmse:7393853.50000
#
# params: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 2.0}, logloss: 7393853.5488
# [0]	train-rmse:29435498.00000	eval-rmse:30996432.00000
#
# [1]	train-rmse:21856338.00000	eval-rmse:23261902.00000
#
# [2]	train-rmse:16512384.00000	eval-rmse:17791948.00000
#
# [3]	train-rmse:12948883.00000	eval-rmse:14249404.00000
#
# [4]	train-rmse:10561686.00000	eval-rmse:11899757.00000
#
# [5]	train-rmse:9022625.00000	eval-rmse:10528783.00000
#
# [6]	train-rmse:8000077.00000	eval-rmse:9608707.00000
#
# [7]	train-rmse:7363537.00000	eval-rmse:9003137.00000
#
# [8]	train-rmse:6940701.00000	eval-rmse:8672446.00000
#
# [9]	train-rmse:6630110.50000	eval-rmse:8382009.00000
#
# [10]	train-rmse:6428173.00000	eval-rmse:8191263.50000
#
# [11]	train-rmse:6277395.50000	eval-rmse:8045167.50000
#
# [12]	train-rmse:6149126.50000	eval-rmse:7874277.00000
#
# [13]	train-rmse:6054452.50000	eval-rmse:7802811.00000
#
# [14]	train-rmse:5985863.50000	eval-rmse:7747307.50000
#
# [15]	train-rmse:5927789.50000	eval-rmse:7704989.50000
#
# [16]	train-rmse:5874855.00000	eval-rmse:7633625.50000
#
# [17]	train-rmse:5832362.50000	eval-rmse:7622495.00000
#
# [18]	train-rmse:5801897.50000	eval-rmse:7644672.50000
#
# [19]	train-rmse:5751878.50000	eval-rmse:7609604.50000
#
# [20]	train-rmse:5721165.00000	eval-rmse:7573632.00000
#
# [21]	train-rmse:5687584.00000	eval-rmse:7557002.50000
#
# [22]	train-rmse:5667326.00000	eval-rmse:7569313.50000
#
# [23]	train-rmse:5626065.50000	eval-rmse:7549591.50000
#
# [24]	train-rmse:5595825.50000	eval-rmse:7529992.00000
#
# [25]	train-rmse:5557620.00000	eval-rmse:7517438.50000
#
# [26]	train-rmse:5541235.50000	eval-rmse:7482853.00000
#
# [27]	train-rmse:5529388.50000	eval-rmse:7475326.00000
#
# [28]	train-rmse:5485285.00000	eval-rmse:7434401.00000
#
# [29]	train-rmse:5477882.00000	eval-rmse:7420752.50000
#
# [30]	train-rmse:5462114.00000	eval-rmse:7402890.00000
#
# [31]	train-rmse:5456690.00000	eval-rmse:7391698.50000
# [32]	train-rmse:5438668.00000	eval-rmse:7391925.00000
#
# [33]	train-rmse:5424165.50000	eval-rmse:7374377.50000
#
# [34]	train-rmse:5394249.00000	eval-rmse:7367628.50000
#
# [35]	train-rmse:5375711.00000	eval-rmse:7358249.00000
#
# [36]	train-rmse:5371854.50000	eval-rmse:7347002.50000
#
# [37]	train-rmse:5348478.50000	eval-rmse:7345444.00000
#
# [38]	train-rmse:5317074.00000	eval-rmse:7302764.50000
#
# [39]	train-rmse:5297084.00000	eval-rmse:7316342.00000
#
# [40]	train-rmse:5261023.00000	eval-rmse:7316710.50000
#
# [41]	train-rmse:5240635.50000	eval-rmse:7300680.00000
#
# [42]	train-rmse:5222598.00000	eval-rmse:7286294.50000
#
# [43]	train-rmse:5191548.00000	eval-rmse:7269907.50000
#
# [44]	train-rmse:5173507.50000	eval-rmse:7281817.50000
#
# [45]	train-rmse:5158345.50000	eval-rmse:7236780.00000
#
# [46]	train-rmse:5156636.50000	eval-rmse:7228653.50000
#
# [47]	train-rmse:5141844.00000	eval-rmse:7234326.50000
#
# [48]	train-rmse:5130183.00000	eval-rmse:7240131.00000
#
# [49]	train-rmse:5126739.50000	eval-rmse:7225640.00000
#
# params: {'gamma': 0.2, 'max_depth': 4, 'min_child_weight': 5.0}, logloss: 7225639.5285
# [0]	train-rmse:29308058.00000	eval-rmse:30845108.00000
#
# [1]	train-rmse:21543148.00000	eval-rmse:22950648.00000
#
# [2]	train-rmse:16203384.00000	eval-rmse:17685540.00000
#
# [3]	train-rmse:12536206.00000	eval-rmse:13996375.00000
#
# [4]	train-rmse:10054731.00000	eval-rmse:11640016.00000
#
# [5]	train-rmse:8460549.00000	eval-rmse:10170792.00000
#
# [6]	train-rmse:7408277.00000	eval-rmse:9292925.00000
#
# [7]	train-rmse:6743514.00000	eval-rmse:8666985.00000
#
# [8]	train-rmse:6315008.00000	eval-rmse:8313878.00000
#
# [9]	train-rmse:6021896.50000	eval-rmse:8060053.50000
#
# [10]	train-rmse:5803313.00000	eval-rmse:7924316.00000
#
# [11]	train-rmse:5627991.00000	eval-rmse:7745472.00000
#
# [12]	train-rmse:5484968.00000	eval-rmse:7678496.50000
#
# [13]	train-rmse:5367827.00000	eval-rmse:7529657.00000
#
# [14]	train-rmse:5300527.50000	eval-rmse:7479091.00000
#
# [15]	train-rmse:5210458.50000	eval-rmse:7429586.50000
#
# [16]	train-rmse:5177520.00000	eval-rmse:7412217.50000
#
# [17]	train-rmse:5122024.50000	eval-rmse:7375107.00000
#
# [18]	train-rmse:5056193.00000	eval-rmse:7372055.50000
#
# [19]	train-rmse:5022044.50000	eval-rmse:7371677.50000
#
# [20]	train-rmse:5009197.50000	eval-rmse:7344767.00000
#
# [21]	train-rmse:4957153.00000	eval-rmse:7324550.00000
#
# [22]	train-rmse:4943729.00000	eval-rmse:7318884.50000
#
# [23]	train-rmse:4922283.50000	eval-rmse:7304239.50000
#
# [24]	train-rmse:4901075.00000	eval-rmse:7295668.00000
#
# [25]	train-rmse:4849035.00000	eval-rmse:7298881.00000
#
# [26]	train-rmse:4794546.00000	eval-rmse:7320017.50000
#
# [27]	train-rmse:4729994.00000	eval-rmse:7273132.50000
#
# [28]	train-rmse:4711779.00000	eval-rmse:7273587.50000
#
# [29]	train-rmse:4674977.50000	eval-rmse:7251341.50000
#
# [30]	train-rmse:4626347.50000	eval-rmse:7237152.50000
#
# [31]	train-rmse:4592186.00000	eval-rmse:7203130.50000
#
# [32]	train-rmse:4574974.00000	eval-rmse:7207800.00000
#
# [33]	train-rmse:4540607.00000	eval-rmse:7210998.00000
#
# [34]	train-rmse:4529652.00000	eval-rmse:7211502.50000
#
# [35]	train-rmse:4520498.00000	eval-rmse:7215332.50000
#
# [36]	train-rmse:4488373.50000	eval-rmse:7208718.50000
#
# [37]	train-rmse:4476729.00000	eval-rmse:7210482.50000
#
# [38]	train-rmse:4459328.00000	eval-rmse:7199135.00000
#
# [39]	train-rmse:4432120.50000	eval-rmse:7189760.50000
#
# [40]	train-rmse:4426495.00000	eval-rmse:7194091.50000
#
# [41]	train-rmse:4405410.00000	eval-rmse:7197335.00000
#
# [42]	train-rmse:4375453.00000	eval-rmse:7189087.00000
#
# [43]	train-rmse:4357576.00000	eval-rmse:7181941.00000
#
# [44]	train-rmse:4329429.50000	eval-rmse:7188283.00000
#
# [45]	train-rmse:4317088.00000	eval-rmse:7176842.00000
#
# [46]	train-rmse:4314359.00000	eval-rmse:7183506.00000
#
# [47]	train-rmse:4306452.00000	eval-rmse:7180470.50000
# [48]	train-rmse:4291274.50000	eval-rmse:7179207.50000
#
# [49]	train-rmse:4271636.50000	eval-rmse:7192526.00000
#
# params: {'gamma': 0.1, 'max_depth': 5, 'min_child_weight': 2.0}, logloss: 7192525.9042
# [0]	train-rmse:29197456.00000	eval-rmse:30748972.00000
#
# [1]	train-rmse:21326804.00000	eval-rmse:22743830.00000
#
# [2]	train-rmse:15828735.00000	eval-rmse:17301856.00000
#
# [3]	train-rmse:12045661.00000	eval-rmse:13631660.00000
#
# [4]	train-rmse:9465156.00000	eval-rmse:11343278.00000
#
# [5]	train-rmse:7760337.00000	eval-rmse:9883306.00000
#
# [6]	train-rmse:6617483.00000	eval-rmse:8987149.00000
#
# [7]	train-rmse:5866204.00000	eval-rmse:8425299.00000
#
# [8]	train-rmse:5372058.00000	eval-rmse:8136081.50000
#
# [9]	train-rmse:5035252.00000	eval-rmse:7967821.00000
#
# [10]	train-rmse:4783462.50000	eval-rmse:7878161.50000
#
# [11]	train-rmse:4621528.50000	eval-rmse:7812849.50000
#
# [12]	train-rmse:4512511.00000	eval-rmse:7742331.00000
#
# [13]	train-rmse:4419146.00000	eval-rmse:7709514.00000
#
# [14]	train-rmse:4319307.50000	eval-rmse:7695870.00000
#
# [15]	train-rmse:4228999.50000	eval-rmse:7652526.50000
#
# [16]	train-rmse:4182532.50000	eval-rmse:7627037.00000
#
# [17]	train-rmse:4093890.75000	eval-rmse:7609181.50000
#
# [18]	train-rmse:4000038.00000	eval-rmse:7608164.50000
#
# [19]	train-rmse:3965729.00000	eval-rmse:7574885.00000
#
# [20]	train-rmse:3909442.75000	eval-rmse:7580754.00000
#
# [21]	train-rmse:3897583.50000	eval-rmse:7572559.50000
#
# [22]	train-rmse:3890472.50000	eval-rmse:7574969.00000
#
# [23]	train-rmse:3824117.75000	eval-rmse:7581220.00000
#
# [24]	train-rmse:3772633.50000	eval-rmse:7594204.00000
#
# [25]	train-rmse:3736855.75000	eval-rmse:7596610.50000
#
# [26]	train-rmse:3731847.00000	eval-rmse:7597924.50000
#
# [27]	train-rmse:3693136.00000	eval-rmse:7602291.50000
#
# [28]	train-rmse:3664297.50000	eval-rmse:7592612.00000
#
# [29]	train-rmse:3642719.75000	eval-rmse:7595512.00000
#
# [30]	train-rmse:3626741.50000	eval-rmse:7595956.00000
#
# [31]	train-rmse:3567984.50000	eval-rmse:7601565.50000
#
# [32]	train-rmse:3526884.00000	eval-rmse:7567660.50000
#
# [33]	train-rmse:3511000.00000	eval-rmse:7539222.00000
#
# [34]	train-rmse:3474900.00000	eval-rmse:7535951.50000
#
# [35]	train-rmse:3437429.25000	eval-rmse:7532467.50000
#
# [36]	train-rmse:3394417.75000	eval-rmse:7548611.50000
#
# [37]	train-rmse:3374241.50000	eval-rmse:7548372.00000
#
# [38]	train-rmse:3325073.50000	eval-rmse:7563196.50000
#
# [39]	train-rmse:3273135.00000	eval-rmse:7566912.00000
#
# [40]	train-rmse:3263769.75000	eval-rmse:7549440.00000
#
# [41]	train-rmse:3252433.50000	eval-rmse:7537798.50000
#
# [42]	train-rmse:3221852.25000	eval-rmse:7534013.50000
#
# [43]	train-rmse:3195050.25000	eval-rmse:7537883.50000
#
# [44]	train-rmse:3188669.50000	eval-rmse:7548379.00000
#
# [45]	train-rmse:3183631.00000	eval-rmse:7547267.00000
#
# [46]	train-rmse:3179171.00000	eval-rmse:7547578.50000
#
# [47]	train-rmse:3161808.50000	eval-rmse:7558929.00000
#
# [48]	train-rmse:3152964.75000	eval-rmse:7557463.00000
#
# [49]	train-rmse:3142772.00000	eval-rmse:7543764.50000
#
# params: {'gamma': 0.30000000000000004, 'max_depth': 7, 'min_child_weight': 3.0}, logloss: 7543764.2228
# [0]	train-rmse:29179762.00000	eval-rmse:30724742.00000
#
# [1]	train-rmse:21281910.00000	eval-rmse:22728506.00000
#
# [2]	train-rmse:15756601.00000	eval-rmse:17242006.00000
#
# [3]	train-rmse:11911695.00000	eval-rmse:13570031.00000
#
# [4]	train-rmse:9261077.00000	eval-rmse:11306264.00000
#
# [5]	train-rmse:7449150.00000	eval-rmse:9774846.00000
#
# [6]	train-rmse:6211453.50000	eval-rmse:8832150.00000
#
# [7]	train-rmse:5347771.00000	eval-rmse:8360585.00000
#
# [8]	train-rmse:4760912.50000	eval-rmse:8033093.00000
#
# [9]	train-rmse:4341277.50000	eval-rmse:7810536.50000
#
# [10]	train-rmse:3996826.25000	eval-rmse:7667625.00000
#
# [11]	train-rmse:3776617.75000	eval-rmse:7636600.50000
#
# [12]	train-rmse:3572985.50000	eval-rmse:7617627.00000
# [13]	train-rmse:3431083.50000	eval-rmse:7568931.00000
#
# [14]	train-rmse:3339463.50000	eval-rmse:7567750.50000
#
# [15]	train-rmse:3266171.50000	eval-rmse:7564847.50000
#
# [16]	train-rmse:3173496.25000	eval-rmse:7536088.50000
#
# [17]	train-rmse:3101754.75000	eval-rmse:7525839.00000
#
# [18]	train-rmse:3070456.00000	eval-rmse:7520495.50000
#
# [19]	train-rmse:3005150.00000	eval-rmse:7529858.00000
#
# [20]	train-rmse:2963856.50000	eval-rmse:7518665.50000
#
# [21]	train-rmse:2948939.75000	eval-rmse:7505901.50000
#
# [22]	train-rmse:2861936.00000	eval-rmse:7510082.50000
#
# [23]	train-rmse:2793522.25000	eval-rmse:7510990.00000
#
# [24]	train-rmse:2774170.50000	eval-rmse:7504964.50000
#
# [25]	train-rmse:2699181.00000	eval-rmse:7510435.50000
#
# [26]	train-rmse:2673604.75000	eval-rmse:7518500.00000
#
# [27]	train-rmse:2635024.00000	eval-rmse:7520035.00000
#
# [28]	train-rmse:2617976.00000	eval-rmse:7514598.50000
#
# [29]	train-rmse:2534820.25000	eval-rmse:7532732.00000
#
# [30]	train-rmse:2475347.00000	eval-rmse:7536689.00000
#
# [31]	train-rmse:2426633.75000	eval-rmse:7546685.00000
#
# [32]	train-rmse:2406421.00000	eval-rmse:7545933.00000
#
# [33]	train-rmse:2393256.50000	eval-rmse:7545828.00000
#
# [34]	train-rmse:2372650.75000	eval-rmse:7548645.50000
#
# [35]	train-rmse:2352395.75000	eval-rmse:7545873.00000
#
# [36]	train-rmse:2312878.00000	eval-rmse:7533810.50000
#
# [37]	train-rmse:2307938.00000	eval-rmse:7528465.00000
#
# [38]	train-rmse:2288984.75000	eval-rmse:7523556.50000
#
# [39]	train-rmse:2276753.50000	eval-rmse:7526752.00000
#
# [40]	train-rmse:2237434.50000	eval-rmse:7540843.00000
#
# [41]	train-rmse:2224274.00000	eval-rmse:7539159.00000
#
# [42]	train-rmse:2196868.75000	eval-rmse:7538937.50000
#
# [43]	train-rmse:2179898.00000	eval-rmse:7546581.50000
#
# [44]	train-rmse:2154161.00000	eval-rmse:7550523.00000
#
# [45]	train-rmse:2129634.75000	eval-rmse:7549726.50000
#
# [46]	train-rmse:2108572.75000	eval-rmse:7554107.00000
#
# [47]	train-rmse:2104971.00000	eval-rmse:7554749.50000
#
# [48]	train-rmse:2096225.50000	eval-rmse:7557732.50000
#
# [49]	train-rmse:2080047.37500	eval-rmse:7560001.00000
#
# params: {'gamma': 0.2, 'max_depth': 9, 'min_child_weight': 2.0}, logloss: 7560001.3092
# [0]	train-rmse:29308058.00000	eval-rmse:30845108.00000
#
# [1]	train-rmse:21543654.00000	eval-rmse:22938080.00000
#
# [2]	train-rmse:16204349.00000	eval-rmse:17679666.00000
#
# [3]	train-rmse:12532787.00000	eval-rmse:14018040.00000
#
# [4]	train-rmse:10067006.00000	eval-rmse:11684976.00000
#
# [5]	train-rmse:8426179.00000	eval-rmse:10228375.00000
#
# [6]	train-rmse:7372592.50000	eval-rmse:9309364.00000
#
# [7]	train-rmse:6702190.50000	eval-rmse:8660302.00000
#
# [8]	train-rmse:6276236.50000	eval-rmse:8300593.00000
#
# [9]	train-rmse:6000347.50000	eval-rmse:7997816.00000
#
# [10]	train-rmse:5803325.50000	eval-rmse:7872979.00000
#
# [11]	train-rmse:5667606.50000	eval-rmse:7789285.00000
#
# [12]	train-rmse:5519117.50000	eval-rmse:7671810.50000
#
# [13]	train-rmse:5382019.50000	eval-rmse:7502153.50000
#
# [14]	train-rmse:5305443.50000	eval-rmse:7453430.50000
#
# [15]	train-rmse:5224167.00000	eval-rmse:7402756.50000
#
# [16]	train-rmse:5187223.00000	eval-rmse:7378803.50000
#
# [17]	train-rmse:5158592.50000	eval-rmse:7368350.00000
#
# [18]	train-rmse:5084406.00000	eval-rmse:7345349.00000
#
# [19]	train-rmse:5068821.00000	eval-rmse:7330660.50000
#
# [20]	train-rmse:5022225.00000	eval-rmse:7339588.00000
#
# [21]	train-rmse:4985651.00000	eval-rmse:7268107.50000
#
# [22]	train-rmse:4924109.00000	eval-rmse:7243434.00000
#
# [23]	train-rmse:4899335.00000	eval-rmse:7229392.00000
#
# [24]	train-rmse:4865883.00000	eval-rmse:7211032.00000
#
# [25]	train-rmse:4827914.50000	eval-rmse:7220118.00000
#
# [26]	train-rmse:4801557.00000	eval-rmse:7240879.00000
#
# [27]	train-rmse:4796798.50000	eval-rmse:7241446.00000
#
# [28]	train-rmse:4795094.50000	eval-rmse:7237699.50000
# [29]	train-rmse:4754988.00000	eval-rmse:7245392.50000
#
# [30]	train-rmse:4687356.00000	eval-rmse:7216067.00000
#
# [31]	train-rmse:4660442.00000	eval-rmse:7183057.50000
#
# [32]	train-rmse:4643130.50000	eval-rmse:7188991.50000
#
# [33]	train-rmse:4639504.00000	eval-rmse:7184203.50000
#
# [34]	train-rmse:4625270.00000	eval-rmse:7140429.00000
#
# [35]	train-rmse:4596422.50000	eval-rmse:7142141.00000
#
# [36]	train-rmse:4587303.50000	eval-rmse:7141541.50000
#
# [37]	train-rmse:4567300.00000	eval-rmse:7149325.00000
#
# [38]	train-rmse:4527115.00000	eval-rmse:7147020.50000
#
# [39]	train-rmse:4514096.00000	eval-rmse:7151287.50000
#
# [40]	train-rmse:4506979.50000	eval-rmse:7162625.00000
#
# [41]	train-rmse:4503008.50000	eval-rmse:7169598.50000
#
# [42]	train-rmse:4493245.50000	eval-rmse:7177346.50000
#
# [43]	train-rmse:4463687.00000	eval-rmse:7164571.50000
#
# [44]	train-rmse:4433461.00000	eval-rmse:7178347.00000
#
# [45]	train-rmse:4429346.50000	eval-rmse:7180634.00000
#
# [46]	train-rmse:4424965.50000	eval-rmse:7181587.50000
#
# [47]	train-rmse:4404969.50000	eval-rmse:7194024.00000
#
# [48]	train-rmse:4389089.00000	eval-rmse:7197028.00000
#
# [49]	train-rmse:4383555.50000	eval-rmse:7194601.50000
#
# params: {'gamma': 0.2, 'max_depth': 5, 'min_child_weight': 3.0}, logloss: 7194600.6777
# [0]	train-rmse:29307928.00000	eval-rmse:30846662.00000
#
# [1]	train-rmse:21540598.00000	eval-rmse:22944612.00000
#
# [2]	train-rmse:16198077.00000	eval-rmse:17689148.00000
#
# [3]	train-rmse:12529697.00000	eval-rmse:13998705.00000
#
# [4]	train-rmse:10047232.00000	eval-rmse:11640351.00000
#
# [5]	train-rmse:8442567.00000	eval-rmse:10167178.00000
#
# [6]	train-rmse:7391506.00000	eval-rmse:9240750.00000
#
# [7]	train-rmse:6727356.00000	eval-rmse:8610018.00000
#
# [8]	train-rmse:6290225.00000	eval-rmse:8303804.00000
#
# [9]	train-rmse:5983934.00000	eval-rmse:8083098.50000
#
# [10]	train-rmse:5789100.50000	eval-rmse:7925468.50000
#
# [11]	train-rmse:5645549.00000	eval-rmse:7851479.50000
#
# [12]	train-rmse:5522600.00000	eval-rmse:7721108.00000
#
# [13]	train-rmse:5434701.50000	eval-rmse:7640734.00000
#
# [14]	train-rmse:5312251.00000	eval-rmse:7603364.00000
#
# [15]	train-rmse:5246782.50000	eval-rmse:7563073.00000
#
# [16]	train-rmse:5198741.50000	eval-rmse:7556354.00000
#
# [17]	train-rmse:5175147.00000	eval-rmse:7537875.50000
#
# [18]	train-rmse:5082580.50000	eval-rmse:7476042.50000
#
# [19]	train-rmse:5031012.00000	eval-rmse:7428457.00000
#
# [20]	train-rmse:5000027.50000	eval-rmse:7447078.50000
#
# [21]	train-rmse:4935016.50000	eval-rmse:7409615.50000
#
# [22]	train-rmse:4879637.50000	eval-rmse:7410611.00000
#
# [23]	train-rmse:4853498.00000	eval-rmse:7401919.00000
#
# [24]	train-rmse:4835686.50000	eval-rmse:7392356.00000
#
# [25]	train-rmse:4784157.50000	eval-rmse:7384793.50000
#
# [26]	train-rmse:4751607.00000	eval-rmse:7391226.50000
#
# [27]	train-rmse:4686746.50000	eval-rmse:7395548.50000
#
# [28]	train-rmse:4657184.00000	eval-rmse:7391775.50000
#
# [29]	train-rmse:4641958.50000	eval-rmse:7341808.50000
#
# [30]	train-rmse:4634402.00000	eval-rmse:7342609.50000
#
# [31]	train-rmse:4599997.50000	eval-rmse:7337318.00000
#
# [32]	train-rmse:4555705.00000	eval-rmse:7336318.50000
#
# [33]	train-rmse:4504881.50000	eval-rmse:7294232.50000
#
# [34]	train-rmse:4447719.50000	eval-rmse:7314545.00000
#
# [35]	train-rmse:4439312.50000	eval-rmse:7314634.50000
#
# [36]	train-rmse:4435990.50000	eval-rmse:7312369.50000
#
# [37]	train-rmse:4404370.50000	eval-rmse:7306404.00000
#
# [38]	train-rmse:4374362.50000	eval-rmse:7294785.50000
#
# [39]	train-rmse:4330694.50000	eval-rmse:7294462.00000
#
# [40]	train-rmse:4314597.00000	eval-rmse:7270182.00000
#
# [41]	train-rmse:4276975.50000	eval-rmse:7234341.50000
#
# [42]	train-rmse:4259286.50000	eval-rmse:7249126.00000
#
# [43]	train-rmse:4249679.00000	eval-rmse:7257440.50000
#
# [44]	train-rmse:4217618.50000	eval-rmse:7262390.00000
# [45]	train-rmse:4204068.00000	eval-rmse:7257617.50000
#
# [46]	train-rmse:4182157.25000	eval-rmse:7236545.00000
#
# [47]	train-rmse:4158484.75000	eval-rmse:7212256.00000
#
# [48]	train-rmse:4129728.00000	eval-rmse:7210117.50000
#
# [49]	train-rmse:4107439.75000	eval-rmse:7204438.50000
#
# params: {'gamma': 0.2, 'max_depth': 5, 'min_child_weight': 1.0}, logloss: 7204438.6248
# [0]	train-rmse:29181452.00000	eval-rmse:30727258.00000
#
# [1]	train-rmse:21288358.00000	eval-rmse:22730372.00000
#
# [2]	train-rmse:15769544.00000	eval-rmse:17248140.00000
#
# [3]	train-rmse:11954601.00000	eval-rmse:13584226.00000
#
# [4]	train-rmse:9338523.00000	eval-rmse:11253200.00000
#
# [5]	train-rmse:7586000.00000	eval-rmse:9700034.00000
#
# [6]	train-rmse:6336649.00000	eval-rmse:8810154.00000
#
# [7]	train-rmse:5533663.50000	eval-rmse:8346593.00000
#
# [8]	train-rmse:4988397.50000	eval-rmse:8060661.50000
#
# [9]	train-rmse:4584946.50000	eval-rmse:7834191.00000
#
# [10]	train-rmse:4295168.50000	eval-rmse:7756611.00000
#
# [11]	train-rmse:4088025.00000	eval-rmse:7704329.00000
#
# [12]	train-rmse:3924387.75000	eval-rmse:7703825.00000
#
# [13]	train-rmse:3786666.00000	eval-rmse:7670799.00000
#
# [14]	train-rmse:3695654.00000	eval-rmse:7631959.50000
#
# [15]	train-rmse:3625989.25000	eval-rmse:7599232.50000
#
# [16]	train-rmse:3515507.75000	eval-rmse:7585845.00000
#
# [17]	train-rmse:3472481.25000	eval-rmse:7580218.00000
#
# [18]	train-rmse:3427182.25000	eval-rmse:7563168.50000
#
# [19]	train-rmse:3390264.25000	eval-rmse:7569994.50000
#
# [20]	train-rmse:3335131.00000	eval-rmse:7555244.00000
#
# [21]	train-rmse:3288820.25000	eval-rmse:7550749.00000
#
# [22]	train-rmse:3280591.50000	eval-rmse:7557627.50000
#
# [23]	train-rmse:3264862.00000	eval-rmse:7544810.50000
#
# [24]	train-rmse:3210426.50000	eval-rmse:7544287.50000
#
# [25]	train-rmse:3159903.00000	eval-rmse:7541027.50000
#
# [26]	train-rmse:3137285.25000	eval-rmse:7543074.50000
#
# [27]	train-rmse:3108731.50000	eval-rmse:7524514.00000
#
# [28]	train-rmse:3074787.50000	eval-rmse:7530671.50000
#
# [29]	train-rmse:3060675.50000	eval-rmse:7525004.50000
#
# [30]	train-rmse:3020014.25000	eval-rmse:7523488.00000
#
# [31]	train-rmse:2993187.50000	eval-rmse:7530240.00000
#
# [32]	train-rmse:2925902.50000	eval-rmse:7523952.50000
#
# [33]	train-rmse:2871925.75000	eval-rmse:7517349.50000
#
# [34]	train-rmse:2837762.50000	eval-rmse:7517118.00000
#
# [35]	train-rmse:2775047.00000	eval-rmse:7545842.00000
#
# [36]	train-rmse:2768418.25000	eval-rmse:7547007.00000
#
# [37]	train-rmse:2709397.50000	eval-rmse:7568459.00000
#
# [38]	train-rmse:2670623.25000	eval-rmse:7569017.50000
#
# [39]	train-rmse:2655172.75000	eval-rmse:7572482.00000
#
# [40]	train-rmse:2644262.50000	eval-rmse:7565863.50000
#
# [41]	train-rmse:2621725.25000	eval-rmse:7570013.00000
#
# [42]	train-rmse:2592643.50000	eval-rmse:7560888.50000
#
# [43]	train-rmse:2578269.25000	eval-rmse:7566643.00000
#
# [44]	train-rmse:2517281.00000	eval-rmse:7579658.50000
#
# [45]	train-rmse:2478326.75000	eval-rmse:7583921.50000
#
# [46]	train-rmse:2456361.00000	eval-rmse:7586044.00000
#
# [47]	train-rmse:2429178.25000	eval-rmse:7591582.00000
#
# [48]	train-rmse:2411366.75000	eval-rmse:7596607.00000
#
# [49]	train-rmse:2396526.00000	eval-rmse:7600647.00000
#
# params: {'gamma': 0.0, 'max_depth': 8, 'min_child_weight': 2.0}, logloss: 7600646.7026
# [0]	train-rmse:29184762.00000	eval-rmse:30723006.00000
#
# [1]	train-rmse:21302704.00000	eval-rmse:22728124.00000
#
# [2]	train-rmse:15801363.00000	eval-rmse:17250438.00000
#
# [3]	train-rmse:11993199.00000	eval-rmse:13608286.00000
#
# [4]	train-rmse:9393618.00000	eval-rmse:11286563.00000
#
# [5]	train-rmse:7644060.50000	eval-rmse:9778031.00000
#
# [6]	train-rmse:6467633.50000	eval-rmse:8760305.00000
#
# [7]	train-rmse:5715339.50000	eval-rmse:8218299.00000
#
# [8]	train-rmse:5213933.00000	eval-rmse:7922204.00000
#
# [9]	train-rmse:4800482.50000	eval-rmse:7726808.50000
# [10]	train-rmse:4541307.50000	eval-rmse:7611319.00000
#
# [11]	train-rmse:4371276.50000	eval-rmse:7534963.50000
#
# [12]	train-rmse:4230074.00000	eval-rmse:7506927.50000
#
# [13]	train-rmse:4081998.50000	eval-rmse:7500632.00000
#
# [14]	train-rmse:3983694.00000	eval-rmse:7490631.00000
#
# [15]	train-rmse:3915417.00000	eval-rmse:7466450.00000
#
# [16]	train-rmse:3845254.00000	eval-rmse:7461328.00000
#
# [17]	train-rmse:3790541.00000	eval-rmse:7433821.00000
#
# [18]	train-rmse:3771323.25000	eval-rmse:7418501.50000
#
# [19]	train-rmse:3735603.75000	eval-rmse:7409010.00000
#
# [20]	train-rmse:3704222.00000	eval-rmse:7388753.00000
#
# [21]	train-rmse:3676310.25000	eval-rmse:7379274.00000
#
# [22]	train-rmse:3664213.25000	eval-rmse:7369317.00000
#
# [23]	train-rmse:3656261.00000	eval-rmse:7368769.50000
#
# [24]	train-rmse:3620138.75000	eval-rmse:7336077.00000
#
# [25]	train-rmse:3580600.50000	eval-rmse:7339879.50000
#
# [26]	train-rmse:3542801.00000	eval-rmse:7352203.50000
#
# [27]	train-rmse:3506365.50000	eval-rmse:7339868.50000
#
# [28]	train-rmse:3482225.50000	eval-rmse:7340632.00000
#
# [29]	train-rmse:3440381.75000	eval-rmse:7358867.50000
#
# [30]	train-rmse:3359312.75000	eval-rmse:7354024.50000
#
# [31]	train-rmse:3342301.25000	eval-rmse:7351928.00000
#
# [32]	train-rmse:3304389.50000	eval-rmse:7336400.00000
#
# [33]	train-rmse:3274331.00000	eval-rmse:7338091.50000
#
# [34]	train-rmse:3250589.00000	eval-rmse:7320120.00000
#
# [35]	train-rmse:3203134.00000	eval-rmse:7325344.00000
#
# [36]	train-rmse:3181859.25000	eval-rmse:7319049.00000
#
# [37]	train-rmse:3163151.00000	eval-rmse:7334480.00000
#
# [38]	train-rmse:3125175.75000	eval-rmse:7347350.00000
#
# [39]	train-rmse:3085624.75000	eval-rmse:7367658.50000
#
# [40]	train-rmse:3073823.25000	eval-rmse:7364545.00000
#
# [41]	train-rmse:3064396.00000	eval-rmse:7366246.00000
#
# [42]	train-rmse:3029978.00000	eval-rmse:7385145.50000
#
# [43]	train-rmse:2992322.50000	eval-rmse:7383618.50000
#
# [44]	train-rmse:2952550.25000	eval-rmse:7399482.00000
#
# [45]	train-rmse:2933894.75000	eval-rmse:7394904.50000
#
# [46]	train-rmse:2907721.50000	eval-rmse:7406848.00000
#
# [47]	train-rmse:2890618.75000	eval-rmse:7410173.50000
#
# [48]	train-rmse:2884565.75000	eval-rmse:7408440.00000
#
# [49]	train-rmse:2880798.75000	eval-rmse:7411286.50000
#
# params: {'gamma': 0.1, 'max_depth': 8, 'min_child_weight': 4.0}, logloss: 7411286.4575
# 100%|█████████████████████████████████████████████████| 10/10 [00:02<00:00,  3.33trial/s, best loss: 7192525.904156834]
# best params:{'gamma': 0.1, 'max_depth': 5, 'min_child_weight': 2.0}, score:7192525.9042

# %%
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# best params:{'gamma': 0.1, 'max_depth': 5, 'min_child_weight': 2.0}, score:7192525.9042

# %% [markdown]
# ### Another Trial

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
#訓練用と検証用のindexを作成する
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

dtrain = xgb.DMatrix(tr_x, label=tr_y) #xgbのデータ型に変換
dvalid = xgb.DMatrix(va_x, label=va_y)

# %%
params = {'objective':'reg:squarederror', 'silent':1 , 'random_state':71}
num_round =50
watchlist = [(dtrain,'train'),(dvalid,'eval')]

# %%
model = xgb.train(params, dtrain,num_round, evals=watchlist)
# Out:
# [0]	train-rmse:29231778.00000	eval-rmse:30792920.00000
# [1]	train-rmse:21401708.00000	eval-rmse:22767962.00000
# [2]	train-rmse:15945462.00000	eval-rmse:17425754.00000
# [3]	train-rmse:12172091.00000	eval-rmse:13678410.00000
# [4]	train-rmse:9598904.00000	eval-rmse:11204296.00000
# [5]	train-rmse:7945833.50000	eval-rmse:9780067.00000
# [6]	train-rmse:6860563.00000	eval-rmse:8975791.00000
# [7]	train-rmse:6111426.00000	eval-rmse:8413604.00000
# [8]	train-rmse:5663827.50000	eval-rmse:8117376.00000
# [9]	train-rmse:5370885.00000	eval-rmse:7917968.00000
# [10]	train-rmse:5160830.50000	eval-rmse:7747086.00000
# [11]	train-rmse:5027537.00000	eval-rmse:7693710.00000
# [12]	train-rmse:4937834.00000	eval-rmse:7670854.50000
# [13]	train-rmse:4793298.00000	eval-rmse:7652235.50000
# [14]	train-rmse:4706511.50000	eval-rmse:7577021.00000
# [15]	train-rmse:4606752.00000	eval-rmse:7559090.00000
# [16]	train-rmse:4533517.00000	eval-rmse:7552550.50000
# [17]	train-rmse:4466463.00000	eval-rmse:7536730.50000
# [18]	train-rmse:4418774.00000	eval-rmse:7547778.50000
# [19]	train-rmse:4379527.00000	eval-rmse:7513054.00000
# [20]	train-rmse:4331644.00000	eval-rmse:7502425.00000
# [21]	train-rmse:4278326.00000	eval-rmse:7478985.50000
# [22]	train-rmse:4264837.50000	eval-rmse:7463892.50000
# [23]	train-rmse:4197601.00000	eval-rmse:7433198.00000
# [24]	train-rmse:4178116.00000	eval-rmse:7435948.50000
# [25]	train-rmse:4144071.50000	eval-rmse:7427312.00000
# [26]	train-rmse:4118731.75000	eval-rmse:7420758.00000
# [27]	train-rmse:4054640.75000	eval-rmse:7422461.00000
# [28]	train-rmse:4029287.75000	eval-rmse:7426529.00000
# [29]	train-rmse:4004534.50000	eval-rmse:7431181.50000
# [30]	train-rmse:3949520.50000	eval-rmse:7437425.00000
# [31]	train-rmse:3889539.75000	eval-rmse:7424971.50000
# [32]	train-rmse:3836153.00000	eval-rmse:7425211.00000
# [33]	train-rmse:3817112.50000	eval-rmse:7418754.50000
# [34]	train-rmse:3764437.75000	eval-rmse:7406038.00000
# [35]	train-rmse:3739908.25000	eval-rmse:7399606.00000
# [36]	train-rmse:3704098.50000	eval-rmse:7401953.00000
# [37]	train-rmse:3681950.75000	eval-rmse:7385525.50000
# [38]	train-rmse:3655596.75000	eval-rmse:7397706.00000
# [39]	train-rmse:3636865.50000	eval-rmse:7399322.00000
# [40]	train-rmse:3626407.75000	eval-rmse:7392308.00000
# [41]	train-rmse:3600284.50000	eval-rmse:7366655.50000
# [42]	train-rmse:3582947.50000	eval-rmse:7357559.00000
# [43]	train-rmse:3568784.25000	eval-rmse:7346372.50000
# [44]	train-rmse:3564906.00000	eval-rmse:7345999.50000
# [45]	train-rmse:3537911.00000	eval-rmse:7345728.50000
# [46]	train-rmse:3526221.25000	eval-rmse:7339859.50000
# [47]	train-rmse:3517495.25000	eval-rmse:7341261.50000
# [48]	train-rmse:3493474.75000	eval-rmse:7329096.00000
# [49]	train-rmse:3442422.50000	eval-rmse:7330625.00000
